# %% [markdown]
# ### О задании
#
# В данном задании необходимо реализовать обучение линейной регрессии с помощью различных вариантов градиентного спуска.
#
# Баллы даются за выполнение отдельных пунктов (Максимальное количество баллов за эту Л.Р. - 5)
#
# Задачи в рамках одного раздела рекомендуется решать в том порядке, в котором они даны в задании.
#
# Неэффективная реализация кода может негативно отразиться на оценке.
# Также оценка может быть снижена за плохо читаемый код и плохо считываемые диаграммы.
#
# Все ответы должны сопровождаться кодом или комментариями о том, как они были получены.
#
#
# ### Формат сдачи
# Задания сдаются через lms. Вы прикрепляете **ССЫЛКУ НА ПУБЛИЧНЫЙ РЕПОЗИТОРИЙ**, где выполнено ваше задание.

# %% [markdown]
# Приготовьтесь, потому что на лекциях и семинарах мы уже прошли через джунгли теории, оттачивая наши навыки в мастерстве оптимизации функционалов. Мы погружались в глубины градиентного спуска, изучая его в каждом возможном амплуа — от классического полного градиента до беспощадного стохастического градиента, не забывая про метод с импульсом, который как боксерский удар прорывается сквозь проблемы оптимизации.
#
# Теперь же перед вами стоит вызов, который не для слабонервных. Ваша миссия, если вы, конечно, осмелитесь ее принять, — взять в арсенал четыре разнообразных вида градиентного спуска и смастерить из них инструмент, способный расправиться с любой задачей. Вам предстоит создать собственную версию линейной регрессии, такую, что даже самые опытные аналитики данных будут смотреть на нее с завистью. Испытайте на реальных данных весь арсенал вашего градиентного спуска, сравните, какой из них выходит на арену оптимизации как несокрушимый чемпион.
#
# Это задание не для тех, кто привык стоять в сторонке. Это ваш момент славы, ваш шанс выйти на арену, где вашим оружием будет код, а противниками — самые коварные задачи машинного обучения. Покажите, на что вы способны, и пусть ваш код станет легендой!
#
# @GPT-4

# %% [markdown]
# ## Задание 1. Реализация градиентного спуска (1.75 балла)
#
# В этом задании вам предстоит написать собственные реализации различных подходов к градиентному спуску с опорой на подготовленные шаблоны в файле `descents.py`.
#
# **Все реализуемые методы должны быть векторизованы!**

# %% [markdown]
# ### Лирическое размышление № 1
#
# Ключевая характеристика антиградиента заключается в том, что он направлен к самому быстрому уменьшению значения функции в конкретной точке. Исходя из этого, разумным подходом будет начать движение с определенной точки, переместиться в направлении антиградиента, затем вновь вычислить антиградиент, совершить движение и продолжать таким образом. Давайте опишем этот процесс более формализованно.
#
# Предположим, что $w_0$ – это исходный набор параметров (к примеру, набор из нулей или полученный из какого-либо случайного распределения). В этом случае простой градиентный спуск предполагает выполнение следующих действий до достижения сходимости:
#
# $$
#     w_{k + 1} = w_{k} - \eta_{k} \nabla_{w} Q(w_{k}).
# $$

# %% [markdown]
# ### Лирическое размышление № 2
#
# ### Задание 0.0. Градиент MSE в матричном виде (0 баллов).
#
# Напомним, что функция потерь MSE записывается в матричном виде как:
#
# Давайте найдем градиент функции $Q(w)$ по $w$, используя матричное дифференцирование. Функция $Q(w)$ определена как:
#
# $$
# Q(w) = \frac{1}{\ell} (y - Xw)^T (y - Xw)
# $$
#
# где:
# - $Q(w)$ — функция потерь,
# - $\ell$ — количество наблюдений

# %% [markdown]
# - $y$ — вектор истинных значений,
# - $X$ — матрица признаков,
# - $w$ — вектор весов.
#
# Градиент функции потерь $Q(w)$ по $w$ находится следующим образом:
#
# 1. Раскроем скобки в выражении для $Q(w)$:
#
# $$
# Q(w) = \frac{1}{\ell} (y^Ty - y^TXw - w^TX^Ty + w^TX^TXw)
# $$
#
# 2. Заметим, что $y^TXw$ и $w^TX^Ty$ представляют собой скаляры и равны между собой. Тогда выражение упрощается до:
#
# $$
# Q(w) = \frac{1}{\ell} (y^Ty - 2y^TXw + w^TX^TXw)
# $$
#
# 3. Теперь дифференцируем $Q(w)$ по $w$. При дифференцировании $y^Ty$ как константа относительно $w$ исчезает, а дифференциация оставшейся части дает:
#
# $$
# \nabla_w Q(w) = \frac{1}{\ell} (-2X^Ty + 2X^TXw)
# $$
#
# 4. Упростим выражение, вынеся 2 за скобки:
#
# $$
# \nabla_w Q(w) = \frac{2}{\ell} (X^TXw - X^Ty)
# $$
#
# Таким образом, градиент функции потерь $Q(w)$ по вектору весов $w$ равен:
#
# $$
# \nabla_w Q(w) = \frac{2}{\ell} (X^TXw - X^Ty)
# $$
#
# Это выражение и есть искомый градиент.

# %% [markdown]
# ### Лирическое размышление № 4
#
# В процессе оптимизации может случиться так, что направление наискорейшего спуска, определенное антиградиентом, будет резко колебаться от одного шага к другому. Это часто происходит, если функция потерь имеет вытянутые уровни, что приводит к тому, что градиент, всегда перпендикулярный этим линиям, меняет свое направление на противоположное при каждом шаге. Эти колебания могут серьезно замедлить сходимость оптимизационного процесса из-за постоянных "колебаний" в обратных направлениях. Чтобы сгладить эти осцилляции и ускорить процесс оптимизации, применяется метод усреднения градиентов из нескольких предыдущих шагов, тем самым снижая "шум" и выявляя общее предпочтительное направление движения. Это достигается с помощью введения вектора инерции:
#
# \begin{align}
#     &h_0 = 0, \\
#     &h_{k + 1} = \alpha h_{k} + \eta_k \nabla_w Q(w_{k}),
# \end{align}
#
# где $\alpha$ — коэффициент, контролирующий влияние градиентов предыдущих шагов, уменьшая их вклад со временем. Можно использовать аппроксимацию градиента для вычисления $h_{k + 1}$. Для осуществления следующего шага градиентного спуска текущую точку смещают на вектор инерции:
#
# $$
#     w_{k + 1} = w_{k} - h_{k + 1}.
# $$
#
# Такой подход позволяет сгладить колебания градиента: если градиент по какому-то направлению часто меняет знак, его вклад в вектор инерции будет уменьшаться, в то время как постоянное направление градиента приведет к увеличению шага в этом направлении, делая процесс оптимизации более стабильным и направленным.

# %% [markdown]
# ### Задание 1.4 Метод Momentum MomentumDescent (0.25 балла).
#
# Реализуйте градиентный спуск с методом инерции заполнив пропуски в классе `MomentumDescent`. Шаг оптимизации:
#
# \begin{align}
#     &h_0 = 0, \\
#     &h_{k + 1} = \alpha h_{k} + \eta_k \nabla_w Q(w_{k}) \\
#     &w_{k + 1} = w_{k} - h_{k + 1}.
# \end{align}
#
# $\alpha$ будет являться гиперпараметром метода, но в данном домашнем задании мы зафиксируем её за вас $\alpha = 0.9$.

# %% [markdown]
# ### Лирическо размышление № 5
#
# Выбор размера шага играет критическую роль в эффективности градиентного спуска. Слишком большой шаг может привести к тому, что процесс будет "перепрыгивать" минимальное значение, а слишком маленький шаг существенно замедлит достижение минимума, требуя большего количества итераций. Предварительно определить идеальный размер шага невозможно, и даже стратегии постепенного его уменьшения могут оказаться неэффективными.
#
# AdaGrad предлагает индивидуальный подход к регулированию длины шага для каждой отдельной компоненты параметров. Суть метода заключается в уменьшении размера шага в зависимости от общей длины предыдущих шагов по данному параметру:
#
# \begin{align}
#     &G_{kj} = G_{k-1,j} + (\nabla_w Q(w_{k - 1}))_j^2; \\
#     &w_{jk} = w_{j,k-1} - \frac{\eta_t}{\sqrt{G_{kj}} + \varepsilon} (\nabla_w Q(w_{k - 1}))_j.
# \end{align}
#
# Где $\varepsilon$ — малая добавка для предотвращения деления на ноль.
#
# В AdaGrad размер шага может быть фиксирован с самого начала, исключая необходимость его подбора в процессе. Этот метод особенно эффективен в задачах с разреженными данными, где большинство признаков для объектов равны нулю. Таким образом, большие шаги будут совершаться по редко встречающимся признакам, в то время как по часто встречающимся — маленькие.
#
# Основной недостаток AdaGrad заключается в неизбежном замедлении шагов из-за монотонного роста $G_{kj}$, что может остановить процесс до достижения оптимального решения. Эту проблему решает метод RMSprop, где применяется экспоненциальное сглаживание для градиентов:
#
# $$
#     G_{kj} = \alpha G_{k-1,j} + (1 - \alpha) (\nabla_w Q(w^{(k-1)}))_j^2.
# $$
#
# Здесь шаг адаптируется в зависимости от интенсивности движения по каждому направлению на недавних итерациях.
#
# Объединяя идеи этих методов, можно достичь эффективного накопления информации о градиентах для стабилизации процесса и внедрить адаптивную длину шага для каждого параметра, обеспечивая более сбалансированное и быстрое приближение к минимуму.

# %% [markdown]
# ### Лирическо размышление № 5
#
# Выбор размера шага играет критическую роль в эффективности градиентного спуска. Слишком большой шаг может привести к тому, что процесс будет "перепрыгивать" минимальное значение, а слишком маленький шаг существенно замедлит достижение минимума, требуя большего количества итераций. Предварительно определить идеальный размер шага невозможно, и даже стратегии постепенного его уменьшения могут оказаться неэффективными.
#
# AdaGrad предлагает индивидуальный подход к регулированию длины шага для каждой отдельной компоненты параметров. Суть метода заключается в уменьшении размера шага в зависимости от общей длины предыдущих шагов по данному параметру:
#
# \begin{align}
#     &G_{kj} = G_{k-1,j} + (\nabla_w Q(w_{k - 1}))_j^2; \\
#     &w_{jk} = w_{j,k-1} - \frac{\eta_t}{\sqrt{G_{kj}} + \varepsilon} (\nabla_w Q(w_{k - 1}))_j.
# \end{align}
#
# Где $\varepsilon$ — малая добавка для предотвращения деления на ноль.
#
# В AdaGrad размер шага может быть фиксирован с самого начала, исключая необходимость его подбора в процессе. Этот метод особенно эффективен в задачах с разреженными данными, где большинство признаков для объектов равны нулю. Таким образом, большие шаги будут совершаться по редко встречающимся признакам, в то время как по часто встречающимся — маленькие.
#
# Основной недостаток AdaGrad заключается в неизбежном замедлении шагов из-за монотонного роста $G_{kj}$, что может остановить процесс до достижения оптимального решения. Эту проблему решает метод RMSprop, где применяется экспоненциальное сглаживание для градиентов:
#
# $$
#     G_{kj} = \alpha G_{k-1,j} + (1 - \alpha) (\nabla_w Q(w^{(k-1)}))_j^2.
# $$
#
# Здесь шаг адаптируется в зависимости от интенсивности движения по каждому направлению на недавних итерациях.
#
# Объединяя идеи этих методов, можно достичь эффективного накопления информации о градиентах для стабилизации процесса и внедрить адаптивную длину шага для каждого параметра, обеспечивая более сбалансированное и быстрое приближение к минимуму.

# %% [markdown]
# ### Лирическо размышление № 5
#
# Выбор размера шага играет критическую роль в эффективности градиентного спуска. Слишком большой шаг может привести к тому, что процесс будет "перепрыгивать" минимальное значение, а слишком маленький шаг существенно замедлит достижение минимума, требуя большего количества итераций. Предварительно определить идеальный размер шага невозможно, и даже стратегии постепенного его уменьшения могут оказаться неэффективными.
#
# AdaGrad предлагает индивидуальный подход к регулированию длины шага для каждой отдельной компоненты параметров. Суть метода заключается в уменьшении размера шага в зависимости от общей длины предыдущих шагов по данному параметру:
#
# \begin{align}
#     &G_{kj} = G_{k-1,j} + (\nabla_w Q(w_{k - 1}))_j^2; \\
#     &w_{jk} = w_{j,k-1} - \frac{\eta_t}{\sqrt{G_{kj}} + \varepsilon} (\nabla_w Q(w_{k - 1}))_j.
# \end{align}
#
# Где $\varepsilon$ — малая добавка для предотвращения деления на ноль.
#
# В AdaGrad размер шага может быть фиксирован с самого начала, исключая необходимость его подбора в процессе. Этот метод особенно эффективен в задачах с разреженными данными, где большинство признаков для объектов равны нулю. Таким образом, большие шаги будут совершаться по редко встречающимся признакам, в то время как по часто встречающимся — маленькие.
#
# Основной недостаток AdaGrad заключается в неизбежном замедлении шагов из-за монотонного роста $G_{kj}$, что может остановить процесс до достижения оптимального решения. Эту проблему решает метод RMSprop, где применяется экспоненциальное сглаживание для градиентов:
#
# $$
#     G_{kj} = \alpha G_{k-1,j} + (1 - \alpha) (\nabla_w Q(w^{(k-1)}))_j^2.
# $$
#
# Здесь шаг адаптируется в зависимости от интенсивности движения по каждому направлению на недавних итерациях.
#
# Объединяя идеи этих методов, можно достичь эффективного накопления информации о градиентах для стабилизации процесса и внедрить адаптивную длину шага для каждого параметра, обеспечивая более сбалансированное и быстрое приближение к минимуму.

# %% [markdown]
# ### Задание 1.5. Метод Adam (Adaptive Moment Estimation) (0.75 балла).
#
# Реализуйте градиентный спуск с методом Adam заполнив пропуски в классе `Adam`. Шаг оптимизации:
#
# \begin{align}
#     &m_0 = 0, \quad v_0 = 0; \\ \\
#     &m_{k + 1} = \beta_1 m_k + (1 - \beta_1) \nabla_w Q(w_{k}); \\ \\
#     &v_{k + 1} = \beta_2 v_k + (1 - \beta_2) \left(\nabla_w Q(w_{k})\right)^2; \\ \\
#     &\widehat{m}_{k} = \dfrac{m_k}{1 - \beta_1^{k}}, \quad \widehat{v}_{k} = \dfrac{v_k}{1 - \beta_2^{k}}; \\ \\
#     &w_{k + 1} = w_{k} - \dfrac{\eta_k}{\sqrt{\widehat{v}_{k + 1}} + \varepsilon} \widehat{m}_{k + 1}.
# \end{align}
#
# $\beta_1 = 0.9, \beta_2 = 0.999$ и $\varepsilon = 10^{-8}$ будут зафиксированы за вас.

# %% [markdown]
# ### Задание 1.5. Метод Adam (Adaptive Moment Estimation) (0.75 балла).
#
# Реализуйте градиентный спуск с методом Adam заполнив пропуски в классе `Adam`. Шаг оптимизации:
#
# \begin{align}
#     &m_0 = 0, \quad v_0 = 0; \\ \\
#     &m_{k + 1} = \beta_1 m_k + (1 - \beta_1) \nabla_w Q(w_{k}); \\ \\
#     &v_{k + 1} = \beta_2 v_k + (1 - \beta_2) \left(\nabla_w Q(w_{k})\right)^2; \\ \\
#     &\widehat{m}_{k} = \dfrac{m_k}{1 - \beta_1^{k}}, \quad \widehat{v}_{k} = \dfrac{v_k}{1 - \beta_2^{k}}; \\ \\
#     &w_{k + 1} = w_{k} - \dfrac{\eta_k}{\sqrt{\widehat{v}_{k + 1}} + \varepsilon} \widehat{m}_{k + 1}.
# \end{align}
#
# $\beta_1 = 0.9, \beta_2 = 0.999$ и $\varepsilon = 10^{-8}$ будут зафиксированы за вас.

# %% [markdown]
# ## Задание 2. Реализация линейной регресии (0.25 балла)
#
# Ваша задача — создать собственную версию линейной регрессии, которая будет обучаться с помощью метода градиентного спуска, следуя предоставленным шаблонам в файле `linear_regression.py` под классом **LinearRegression**. Главные требования к реализации:
#
# - Используйте векторизацию для всех вычислений, минимизируйте использование циклов в Python, за исключением итераций градиентного спуска.
# - Прекращайте обучение, когда выполнено хотя бы одно из следующих условий:
#   - Евклидова норма разности векторов весов между двумя последовательными итерациями становится меньше заданного порога `tolerance`.
#   - В векторе весов появляются значения NaN.
#   - Достигнуто максимальное количество итераций `max_iter`.
# - Предполагается, что данные для обучения уже содержат столбец из единиц в качестве последнего столбца, обеспечивающего вектор свободных членов.
# - Для отслеживания процесса сходимости используйте массив `loss_history`, куда следует записывать значения функции потерь до начала первого шага градиентного спуска и после каждой итерации, включая итоговое значение после завершения обучения.

# %% [markdown]
# ## Задание 3. Проверка кода (0 баллов)

# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2

import numpy as np

from descents import get_descent
from linear_regression import LinearRegression

# %%
num_objects = 100
dimension = 5

x = np.random.rand(num_objects, dimension)
y = np.random.rand(num_objects)

# %%
descent_config = {
    'descent_name': 'типа что-то делает',
    'kwargs': {
        'dimension': dimension
    }
}

for descent_name in ['full', 'stochastic', 'momentum', 'adam']:
    descent_config['descent_name'] = descent_name
    descent = get_descent(descent_config)

    diff = descent.step(x, y)
    gradient = descent.calc_gradient(x, y)
    predictions = descent.predict(x)

    assert gradient.shape[0] == dimension, f'Gradient failed for descent {descent_name}'
    assert diff.shape[0] == dimension, f'Weights failed for descent {descent_name}'
    assert predictions.shape == y.shape, f'Prediction failed for descent {descent_name}'

# %%
# LinearRegression

max_iter = 10
tolerance = 0

descent_config = {
    'descent_name': 'stochastic',
    'kwargs': {
        'dimension': dimension,
        'batch_size': 10
    }
}

regression = LinearRegression(
    descent_config=descent_config,
    tolerance=tolerance,
    max_iter=max_iter
)

regression.fit(x, y)

assert len(regression.loss_history) == max_iter + 1, 'Loss history failed'
# Out:
# Total iterations: 10

# %% [markdown]
# ## Задание 4. Работа с данными (0.5 балла)
#
# Мы будем использовать датасет объявлений по продаже машин на немецком Ebay. В задаче предсказания целевой переменной для нас будет являться цена.

# %% [markdown]
# Вам нужно выполнить базовый EDA анализ:
#
# 1. **Визуализация распределения целевой переменной**:
#     - Постройте график распределения целевой переменной, чтобы оценить его форму.
#     - Если распределение сильно скошено, рассмотрите возможность применения логарифмического преобразования к целевой переменной для нормализации распределения.
#     - Оцените наличие выбросов, аномально высоких или низких значений целевой переменной, используя графический метод или статистические меры (например, интерквартильный размах).
#
# 2. **Удаление выбросов**:
#     - Если в данных присутствуют выбросы с аномальной ценой, удалите их, чтобы они не искажали результаты анализа и моделирования.
#
# 3. **Исследование данных**:
#     - Проанализируйте типы данных в столбцах (категориальные, числовые, текстовые и т.д.).
#     - Постройте графики для анализа зависимости целевой переменной от других признаков. Это поможет понять, какие признаки влияют на целевую переменную.
#     - Изучите распределения значений признаков для выявления аномалий и выбросов. Определите, какие признаки требуют предварительной обработки или трансформации.
#     - На основе графиков и анализа определите, какие признаки кажутся полезными для моделирования.
#
# 4. **Предобработка данных**:
#     - Определите, какие трансформации данных (например, нормализация, стандартизация, кодирование категориальных переменных) могут быть применены к признакам.
#     - Разделите признаки на категории: категориальные, числовые (вещественные) и те, которые не требуют предобработки.
#
# 5. **Разделение данных на выборки**:
#     - Разделите ваши данные на обучающую, валидационную и тестовую выборки в пропорции 8:1:1. Это важный шаг для оценки производительности модели и избежания переобучения.

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from descents import get_descent
from linear_regression import LinearRegression
from sklearn.metrics import mean_squared_error
sns.set(style='darkgrid')

# %%
data = pd.read_csv('autos.csv')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="darkgrid", rc={"figure.figsize": (10, 6)})

sns.histplot(data['price'], kde=True, color='skyblue', edgecolor='white').set(title='Распределение цены', xlabel='Цена', ylabel='Плотность')
plt.show()

# %% [markdown]
# Колонки в данных:
#
# * `brand` - название бренда автомобиля
# * `model` - название модели автомобиля
# * `vehicleType` - тип транспортного средства
# * `gearbox` - тип трансмисcии
# * `fuelType` - какой вид топлива использует автомобиль
# * `notRepairedDamage` - есть ли в автомобиле неисправность, которая еще не устранена
# * `powerPS` - мощность автомобиля в PS (метрическая лошадиная сила)
# * `kilometer` - сколько километров проехал автомобиль, пробег
# * `autoAgeMonths` - возраст автомобиля в месяцах
#
#
# * `price` - цена, указанная в объявлении о продаже автомобиля (целевая переменная)

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

data['log_price'] = np.log1p(data['price'])

sns.set(style="darkgrid", rc={"figure.figsize": (10, 6)})
sns.histplot(data['log_price'], kde=True, color='skyblue', edgecolor='white').set(title='Распределение логарифма цены', xlabel='Логарифм цены', ylabel='Плотность')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="darkgrid", rc={"figure.figsize": (10, 6)})
sns.boxplot(x=data['log_price']).set(title='Диаграмма цены', xlabel='Цена')
plt.show()

# %%
Q1 = data['log_price'].quantile(0.25)
Q3 = data['log_price'].quantile(0.75)
IQR = Q3 - Q1
data_1 = data[~((data['log_price'] < (Q1 - 1.5 * IQR)) | (data['log_price'] > (Q3 + 1.5 * IQR)))]

print(f'Нижняя граница: {Q1 - 1.5 * IQR}')
print(f'Верхняя граница: {Q3 + 1.5 * IQR}')
print(f'Количество записей без выбросов: {data_1.shape[0]}')
# Out:
# Нижняя граница: 5.012386046237095
# Верхняя граница: 11.560536142367114
# Количество записей без выбросов: 240399

# %%
categorical = ['brand', 'model', 'vehicleType', 'gearbox', 'fuelType', 'notRepairedDamage']
numeric = ['powerPS', 'kilometer', 'autoAgeMonths']
other = []

# %%
import seaborn as sns
import matplotlib.pyplot as plt

numeric = ['powerPS', 'kilometer', 'autoAgeMonths']

def plot_scatter(column_name):
    plt.figure(figsize=(10, 6))
    # Использование палитры 'viridis' для визуализации
    sns.scatterplot(x=column_name, y='log_price', data=data_1, palette='viridis', hue=column_name, size=column_name, sizes=(20, 200), alpha=0.6, edgecolor=None)
    plt.title(f'Зависимость цены от {column_name}', fontsize=14)
    plt.xlabel(column_name, fontsize=12)
    plt.ylabel('Логарифм цены', fontsize=12)
    plt.legend(title=column_name, title_fontsize='13', labelspacing=1.2)
    plt.grid(True, linestyle='--', alpha=0.5) # Добавление сетки
    plt.show()

for column in numeric:
    plot_scatter(column)

# %%
plt.figure(figsize=(10, 6))
sns.kdeplot(x=data_1['kilometer'], y=data_1['log_price'], cmap="Blues", fill=True, thresh=0, levels=100, cbar=True, cbar_kws={'label': 'Плотность'})
plt.xlabel('Пробег (километров)', fontsize=12)
plt.ylabel('Логарифм цены', fontsize=12)
plt.title('KDE plot зависимости цены от пробега', fontsize=14)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

def plot_box(column_name):
    plt.figure(figsize=(12, 8))
    sns.boxplot(x=column_name, y='log_price', data=data_1)
    plt.xticks(rotation=45)
    plt.title(f'Зависимость цены от {column_name}', fontsize=14)
    plt.xlabel(column_name, fontsize=12)
    plt.ylabel('Логарифм цены', fontsize=12)
    plt.show()

for column in categorical:
    plot_box(column)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def plot_bar(column, data_to_draw):
    median_prices = data_to_draw.groupby(column)['log_price'].median().sort_values()
    
    plt.figure(figsize=(10, 8))
    sns.barplot(y=median_prices.index, x=median_prices.values, palette="coolwarm")
    
    plt.title(f'Медианная цена автомобилей по {column}', fontsize=14)
    plt.ylabel(column, fontsize=12)
    plt.xlabel('Медианная цена (Логарифм цены)', fontsize=12)
    plt.grid(axis='x', linestyle='--')
    
    plt.show()

plot_bar("brand", data_1)
# Out:
# /tmp/ipykernel_48781/497335199.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=median_prices.index, x=median_prices.values, palette="coolwarm")

# %%
top_models = data['model'].value_counts().head(15).index
top_models_data = data[data['model'].isin(top_models)] 

plot_bar("model", top_models_data)
# Out:
# /tmp/ipykernel_48781/497335199.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=median_prices.index, x=median_prices.values, palette="coolwarm")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

numerical_features = ['powerPS', 'kilometer', 'autoAgeMonths']

sns.set(style="whitegrid", rc={"figure.figsize": (10, 4)})

for feature in numerical_features:
    plt.figure()
    sns.boxplot(x=data_1[feature], palette="coolwarm")
    plt.title(f'Box Plot for {feature}', fontsize=14)
    plt.xlabel(feature, fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.show()
# Out:
# /tmp/ipykernel_48781/2898235745.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=data_1[feature], palette="coolwarm")
# /tmp/ipykernel_48781/2898235745.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=data_1[feature], palette="coolwarm")
# /tmp/ipykernel_48781/2898235745.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=data_1[feature], palette="coolwarm")

# %%
data_1 = data_1.copy()
data_1['bias'] = 1
other += ['bias']

x = data_1[categorical + numeric + other]
y = data_1['log_price']

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler


column_transformer = ColumnTransformer([
    ('ohe', OneHotEncoder(handle_unknown='ignore'), categorical),
    ('scaling', StandardScaler(), numeric),
    ('other',  'passthrough', other)
])

x = column_transformer.fit_transform(x)

# %%
#╰( ͡☉ ͜ʖ ͡☉ )つ──☆*:・ﾟ   ฅ^•ﻌ•^ฅ   ʕ•ᴥ•ʔ (data split into train/val/test):
from sklearn.model_selection import train_test_split
x_train_val, x_test, y_train_val, y_test = train_test_split(
    x, y, test_size=0.1, random_state=42
)

x_train, x_val, y_train, y_val = train_test_split(
    x_train_val, y_train_val, test_size=1/9, random_state=42  # 1/9 от обучающей+валидационной выборки составит 10% от всего датасета
)

# %% [markdown]
# ## Задание 5. Сравнение методов градиентного спуска (1 балл)
#
# В этом задании вам предстоит сравнить методы градиентного спуска на подготовленных вами данных из предыдущего задания.

# %% [markdown]
# ### Задание 5.1. Подбор оптимальной длины шага (0.5 балла)
#
# Процесс выбора наиболее подходящего размера шага $\lambda$ для различных методов, с учетом валидационного набора данных, предполагает выполнение следующих шагов:
#
# 1. **Определение диапазона для $\lambda$**: Начните с выбора диапазона значений $\lambda$, используя логарифмическую сетку от $10^{-4}$ до $10^1$, чтобы обеспечить широкий охват потенциально оптимальных значений.
#
# 2. **Перебор значений $\lambda$**: Для каждого значения из выбранной сетки $\lambda$:
#    - Произведите обучение модели на обучающем наборе данных.
#    - Вычислите ошибку на обучающем и валидационном наборах данных.
#    - Определите значение метрики $R^2$ как на обучающем, так и на валидационном наборах.
#    - Зафиксируйте количество итераций, необходимое для достижения сходимости.
#
# 3. **Оценка полученных результатов**:
#    - Составьте графики, отображающие зависимость ошибки от количества итераций для каждого значения $\lambda$ по всем рассматриваемым методам.
#    - Сравните методы на основе скорости сходимости, размера ошибки и значения метрики $R^2$ на различных наборах данных.
#
# 4. **Выбор наилучшего $\lambda$**: Исходя из проведенного анализа, определите наиболее подходящее значение $\lambda$ для каждого метода, обеспечивающее оптимальное сочетание скорости сходимости и качества модели на валидационной выборке.
#
# 5. **Формулировка выводов**: Подведите итоги, указав, какой метод показал наилучшую производительность с точки зрения соотношения скорости сходимости к качеству предсказаний. Также отметьте, как изменение $\lambda$ влияет на результаты каждого из методов.

# %%
# %reload_ext autoreload
# %autoreload 2

import numpy as np

from descents import get_descent
from linear_regression import LinearRegression

# %%
# %autoreload 2
from sklearn.linear_model import SGDRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

from descents import LossFunction 

learning_rates = np.logspace(-4, 1, num=6)

# %%
# %autoreload 2

import numpy as np
import math
import matplotlib.pyplot as plt

from linear_regression import LinearRegression
from descents import LossFunction

descents = ["full", "stochastic", "momentum", "adam"]
learning_rates = np.logspace(-4, 1, num=6)

overall_results = []

for descent_name in descents:
    print(f"\n{'='*40}\n{descent_name.upper()} DESCENT\n{'='*40}")

    loss_histories = []
    convergence_iterations = []
    
    for lr in learning_rates:
        print(f"\n-- Learning Rate: {lr:.1e} --")
        
        descent_config = {
            'descent_name': descent_name,
            'kwargs': {
                'dimension': x_train.shape[1],
                'lambda_': lr,
                'loss_function': LossFunction.MSE
            }
        }
        model = LinearRegression(descent_config=descent_config, max_iter=5000)
        
        model.fit(x_train, y_train)
        
        train_loss = model.calc_loss(x_train, y_train)
        val_loss = model.calc_loss(x_val, y_val)

        r2_train = model.score(x_train, y_train)
        r2_val = model.score(x_val, y_val)

        if not math.isnan(train_loss) and not math.isnan(val_loss):
            loss_histories.append((lr, model.loss_history, train_loss, val_loss, r2_train, r2_val))
            convergence_iterations.append(len(model.loss_history))

        print(f"Train Loss: {train_loss:.4f}")
        print(f"Validation Loss: {val_loss:.4f}")
        print(f"R^2 on Training: {r2_train:.4f}")
        print(f"R^2 on Validation: {r2_val:.4f}")
        
    overall_results.append({
        'descent_name': descent_name,
        'loss_histories': loss_histories,
        'convergence_iterations': convergence_iterations
    })
# Out:
# ========================================
# FULL DESCENT
# ========================================
#
# -- Learning Rate: 1.0e-04 --
# Convergence achieved after 185 iterations.
# Total iterations: 185
# Train Loss: 17.0620
# Validation Loss: 16.8938
# R^2 on Training: -12.8112
# R^2 on Validation: -12.6855
#
# -- Learning Rate: 1.0e-03 --
# Total iterations: 5000
# Train Loss: 6.4517
# Validation Loss: 6.4423
# R^2 on Training: -4.2224
# R^2 on Validation: -4.2188
#
# -- Learning Rate: 1.0e-02 --
# Convergence achieved after 2455 iterations.
# Total iterations: 2455
# Train Loss: 0.6667
# Validation Loss: 0.6733
# R^2 on Training: 0.4603
# R^2 on Validation: 0.4545
#
# -- Learning Rate: 1.0e-01 --
# Convergence achieved after 3581 iterations.
# Total iterations: 3581
# Train Loss: 0.3427
# Validation Loss: 0.3569
# R^2 on Training: 0.7226
# R^2 on Validation: 0.7109
#
# -- Learning Rate: 1.0e+00 --
# Total iterations: 5000
# Train Loss: 0.2802
# Validation Loss: 0.2931
# R^2 on Training: 0.7732
# R^2 on Validation: 0.7626
#
# -- Learning Rate: 1.0e+01 --
# /app/labs/lab4/descents.py:301: RuntimeWarning: overflow encountered in multiply
#   gradient = 2 * x.T.dot(error) / len(y)
# /app/labs/lab4/descents.py:270: RuntimeWarning: invalid value encountered in add
#   self.w += weight_difference  # Обновляем веса
# Training stopped due to NaN values in weights.
# Total iterations: 539
# Train Loss: nan
# Validation Loss: nan
# R^2 on Training: 1.0000
# R^2 on Validation: 1.0000
#
# ========================================
# STOCHASTIC DESCENT
# ========================================
#
# -- Learning Rate: 1.0e-04 --
# Convergence achieved after 251 iterations.
# Total iterations: 251
# Train Loss: 24.1164
# Validation Loss: 23.8861
# R^2 on Training: -18.5215
# R^2 on Validation: -18.3500
#
# -- Learning Rate: 1.0e-03 --
# Convergence achieved after 4265 iterations.
# Total iterations: 4265
# Train Loss: 7.6583
# Validation Loss: 7.5982
# R^2 on Training: -5.1992
# R^2 on Validation: -5.1553
#
# -- Learning Rate: 1.0e-02 --
# Convergence achieved after 1738 iterations.
# Total iterations: 1738
# Train Loss: 0.6783
# Validation Loss: 0.6896
# R^2 on Training: 0.4510
# R^2 on Validation: 0.4414
#
# -- Learning Rate: 1.0e-01 --
# Total iterations: 5000
# Train Loss: 0.3492
# Validation Loss: 0.3644
# R^2 on Training: 0.7174
# R^2 on Validation: 0.7048
#
# -- Learning Rate: 1.0e+00 --
# Total iterations: 5000
# Train Loss: 549.5085
# Validation Loss: 554.0553
# R^2 on Training: -443.8107
# R^2 on Validation: -447.8359
#
# -- Learning Rate: 1.0e+01 --
# /app/labs/lab4/descents.py:365: RuntimeWarning: overflow encountered in multiply
#   gradient = 2 * x_batch.T.dot(error_batch) / self.batch_size
# Training stopped due to NaN values in weights.
# Total iterations: 549
# Train Loss: nan
# Validation Loss: nan
# R^2 on Training: 1.0000
# R^2 on Validation: 1.0000
#
# ========================================
# MOMENTUM DESCENT
# ========================================
#
# -- Learning Rate: 1.0e-04 --
# Total iterations: 5000
# Train Loss: 0.4037
# Validation Loss: 0.4170
# R^2 on Training: 0.6732
# R^2 on Validation: 0.6622
#
# -- Learning Rate: 1.0e-03 --
# Total iterations: 5000
# Train Loss: 0.3031
# Validation Loss: 0.3171
# R^2 on Training: 0.7547
# R^2 on Validation: 0.7432
#
# -- Learning Rate: 1.0e-02 --
# Total iterations: 5000
# Train Loss: 0.2678
# Validation Loss: 0.2795
# R^2 on Training: 0.7832
# R^2 on Validation: 0.7736
#
# -- Learning Rate: 1.0e-01 --
# Total iterations: 5000
# Train Loss: 0.2605
# Validation Loss: 0.2725
# R^2 on Training: 0.7891
# R^2 on Validation: 0.7792
#
# -- Learning Rate: 1.0e+00 --
# /app/labs/lab4/descents.py:439: RuntimeWarning: invalid value encountered in add
#   self.h = self.alpha * self.h + eta_k * gradient
# Training stopped due to NaN values in weights.
# Total iterations: 456
# Train Loss: nan
# Validation Loss: nan
# R^2 on Training: 1.0000
# R^2 on Validation: 1.0000
#
# -- Learning Rate: 1.0e+01 --
# Training stopped due to NaN values in weights.
# Total iterations: 169
# Train Loss: nan
# Validation Loss: nan
# R^2 on Training: 1.0000
# R^2 on Validation: 1.0000
#
# ========================================
# ADAM DESCENT
# ========================================
#
# -- Learning Rate: 1.0e-04 --
# Total iterations: 5000
# Train Loss: 3.4485
# Validation Loss: 3.4413
# R^2 on Training: -1.7914
# R^2 on Validation: -1.7877
#
# -- Learning Rate: 1.0e-03 --
# Total iterations: 5000
# Train Loss: 0.2648
# Validation Loss: 0.2762
# R^2 on Training: 0.7856
# R^2 on Validation: 0.7762
#
# -- Learning Rate: 1.0e-02 --
# Total iterations: 5000
# Train Loss: 0.2601
# Validation Loss: 0.2721
# R^2 on Training: 0.7895
# R^2 on Validation: 0.7796
#
# -- Learning Rate: 1.0e-01 --
# Convergence achieved after 2506 iterations.
# Total iterations: 2506
# Train Loss: 0.2600
# Validation Loss: 0.2721
# R^2 on Training: 0.7895
# R^2 on Validation: 0.7796
#
# -- Learning Rate: 1.0e+00 --
# Convergence achieved after 739 iterations.
# Total iterations: 739
# Train Loss: 0.2600
# Validation Loss: 0.2721
# R^2 on Training: 0.7895
# R^2 on Validation: 0.7796
#
# -- Learning Rate: 1.0e+01 --
# Convergence achieved after 792 iterations.
# Total iterations: 792
# Train Loss: 0.2600
# Validation Loss: 0.2721
# R^2 on Training: 0.7895
# R^2 on Validation: 0.7796

# %%
for result in overall_results:
    # Создание списка словарей для каждого результата
    combined_results = [
        {
            'learning_rate': lr,
            'history': history,
            'train_loss': train_loss,
            'val_loss': val_loss,
            'iterations': iterations,
            'r2_train': r2_train,
            'r2_val': r2_val
        }
        for (lr, history, train_loss, val_loss, r2_train, r2_val), iterations 
        in zip(result['loss_histories'], result['convergence_iterations'])
    ]
    
    # Поиск лучшего результата на основе потери на валидационной выборке
    best_result = min(combined_results, key=lambda x: x['val_loss'])
    
    # Подготовка и вывод информации о лучшем результате
    descent_name = result['descent_name']
    print("-" * 40)
    print(f"Метод: {descent_name.upper()}")
    print("-" * 40)
    print(f"Оптимальное значение λ: {best_result['learning_rate']:.5f}")
    print(f"Потеря на тренировочной выборке: {best_result['train_loss']:.4f}")
    print(f"Потеря на валидационной выборке: {best_result['val_loss']:.4f}")
    print(f"Количество итераций до сходимости: {best_result['iterations']}")
    print(f"R^2 на тренировочной выборке: {best_result['r2_train']:.4f}")
    print(f"R^2 на валидационной выборке: {best_result['r2_val']:.4f}\n")
# Out:
# ----------------------------------------
# Метод: FULL
# ----------------------------------------
# Оптимальное значение λ: 1.00000
# Потеря на тренировочной выборке: 0.2802
# Потеря на валидационной выборке: 0.2931
# Количество итераций до сходимости: 5001
# R^2 на тренировочной выборке: 0.7732
# R^2 на валидационной выборке: 0.7626
#
# ----------------------------------------
# Метод: STOCHASTIC
# ----------------------------------------
# Оптимальное значение λ: 0.10000
# Потеря на тренировочной выборке: 0.3492
# Потеря на валидационной выборке: 0.3644
# Количество итераций до сходимости: 5001
# R^2 на тренировочной выборке: 0.7174
# R^2 на валидационной выборке: 0.7048
#
# ----------------------------------------
# Метод: MOMENTUM
# ----------------------------------------
# Оптимальное значение λ: 0.10000
# Потеря на тренировочной выборке: 0.2605
# Потеря на валидационной выборке: 0.2725
# Количество итераций до сходимости: 5001
# R^2 на тренировочной выборке: 0.7891
# R^2 на валидационной выборке: 0.7792
#
# ----------------------------------------
# Метод: ADAM
# ----------------------------------------
# Оптимальное значение λ: 0.01000
# Потеря на тренировочной выборке: 0.2601
# Потеря на валидационной выборке: 0.2721
# Количество итераций до сходимости: 5001
# R^2 на тренировочной выборке: 0.7895
# R^2 на валидационной выборке: 0.7796

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

fig, axes = plt.subplots(len(descents), 1, figsize=(10, 8*len(descents)), sharex=True)
fig.tight_layout(pad=5.0)

for i, result in enumerate(overall_results):
    for lr, history, _, _, _, _ in result['loss_histories']:
        line_style = '-' if lr < 0.01 else '--' if lr < 0.1 else ':'
        axes[i].plot(history, label=f'LR: {lr:.3f}', linestyle=line_style, linewidth=2)
    
    axes[i].set_title(f'Loss History for {result["descent_name"]}', fontsize=16)
    axes[i].set_xlabel('Iteration', fontsize=14)
    axes[i].set_ylabel('Loss', fontsize=14)
    axes[i].set_ylim([0, 1])
    axes[i].tick_params(labelsize=12)  # Увеличение размера меток
    axes[i].legend(fontsize=12)

fig.suptitle('Loss History Across Different Descents', fontsize=20, y=1.05)
plt.show()

# %% [markdown]
# ### Задание 5.2. Сравнение методов (0.5 балла)
#
# Создайте график, на котором будет показана динамика изменения ошибки на обучающей выборке в зависимости от номера итерации для каждого из рассматриваемых методов. Разместите линии, представляющие каждый метод, на одном и том же графике для наглядного сравнения.
#
# После анализа результатов, представленных в виде графика и таблиц с метриками, выполните сравнение методов. Обратите внимание на следующие аспекты:
# - Как быстро каждый метод сходится к минимуму ошибки.
# - Величину ошибки на обучающей и тестовой выборках для каждого метода.
# - Значение метрики $R^2$ для каждого метода на обучающей и тестовой выборках.
# - Количество итераций, необходимых для достижения сходимости.
#
# На основе этих данных сделайте вывод о преимуществах и недостатках каждого из методов в контексте вашей задачи.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

plt.figure(figsize=(12, 8))

styles = ['-', '--', '-.', ':']
colors = ['blue', 'red', 'green', 'purple']
labels = ['Full', 'Stochastic', 'Momentum', 'Adam']
loss_histories = [loss_history_full, loss_history_stochastic, loss_history_momentum, loss_history_adam]
iterations = [range(len(loss_history)) for loss_history in loss_histories]

for i, (iteration, loss_history) in enumerate(zip(iterations, loss_histories)):
    plt.plot(iteration, loss_history, label=labels[i], color=colors[i], linestyle=styles[i], linewidth=2)

plt.title('Loss History for Different Gradient Descent Methods', fontsize=18)
plt.xlabel('Iteration', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.ylim(0.25, 1)

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.show()

# %% [markdown]
# В общем, Full метод показывает хорошие результаты по качеству и скорости, но есть методы, работающие быстрее. Стохастический метод оказывается самым медленным по обучению с наименьшим качеством предсказаний, так что, вероятно, не лучший выбор. Метод с Моментом заметно улучшает скорость сходимости по сравнению с Full методом, обещая высокое качество предсказаний. Адам же вырывается вперед как самый быстрый и предлагающий лучшее качество предсказаний метод.
#
# Таким образом, Адам выделяется как наиболее эффективный в плане сочетания скорости и качества предсказаний, хотя Метод с Моментом тоже показывает отличные результаты, немного уступая по скорости.

# %% [markdown]
# ## Задание 6. Стохастический градиентный спуск и размер батча (0.5 балла)
#
# Ваша задача — исследовать, как размер батча влияет на процесс обучения при использовании стохастического градиентного спуска (SGD). Выполните следующие шаги:
#
# 1. **Выбор размеров батча**: Определите ряд значений для размера батча, которые вы хотите исследовать. Это могут быть, например, %1$, $10$, $50$, $100$, $500$, и так далее.
#
# 2. **Многократные запуски для каждого размера батча**: Для каждого выбранного размера батча проведите $k$ независимых запусков стохастического градиентного спуска на обучающей выборке. $k$ может быть равно, например, $10$. Для каждого запуска замерьте:
#    - Время обучения в секундах до достижения сходимости.
#    - Количество итераций (шагов), необходимых для сходимости.
#
# 3. **Вычисление средних значений**: Рассчитайте среднее время обучения и среднее количество итераций до сходимости для каждого размера батча.
#
# 4. **Построение графиков**:
#    - Постройте график, показывающий зависимость среднего количества итераций до сходимости от размера батча.
#    - Постройте график, показывающий зависимость среднего времени обучения от размера батча.
#
# 5. **Анализ результатов**: Оцените, как размер батча влияет на скорость и эффективность обучения. Сделайте выводы о том, какой размер батча может быть оптимальным с точки зрения баланса между временем обучения и количеством итераций до сходимости.
#
# Этот эксперимент поможет вам лучше понять влияние размера батча на процесс обучения стохастического градиентного спуска и как этот параметр можно настроить для улучшения производительности обучения.

# %%
import time  # Для измерения времени обучения

batch_sizes = [1, 10, 50, 100, 500]
k_runs = 6  
results = []

for batch_size in batch_sizes:
    time_per_batch = []
    iterations_per_batch = []

    for run in range(k_runs):
        start_time = time.time()
        descent_config = {
            'descent_name': 'stochastic',
            'kwargs': {
                'dimension': x_train.shape[1],
                'batch_size': batch_size,
                'loss_function': LossFunction.MSE
            }
        }
        model = LinearRegression(descent_config=descent_config, max_iter=4000)
        model.fit(x_train, y_train)
        elapsed_time = time.time() - start_time
        iterations = len(model.loss_history)

        time_per_batch.append(elapsed_time)
        iterations_per_batch.append(iterations)

    avg_time = np.mean(time_per_batch)
    avg_iterations = np.mean(iterations_per_batch)

    results.append({
        'batch_size': batch_size,
        'avg_time': avg_time,
        'avg_iterations': avg_iterations
    })

    print(f"Batch Size: {batch_size}, Avg Time: {avg_time:.2f} sec, Avg Iterations: {avg_iterations}")
# Out:
# Convergence achieved after 79 iterations.
# Total iterations: 79
# Convergence achieved after 84 iterations.
# Total iterations: 84
# Convergence achieved after 742 iterations.
# Total iterations: 742
# Convergence achieved after 211 iterations.
# Total iterations: 211
# Convergence achieved after 205 iterations.
# Total iterations: 205
# Convergence achieved after 495 iterations.
# Total iterations: 495
# Batch Size: 1, Avg Time: 0.48 sec, Avg Iterations: 303.6666666666667
# Convergence achieved after 3241 iterations.
# Total iterations: 3241
# Convergence achieved after 2976 iterations.
# Total iterations: 2976
# Convergence achieved after 2739 iterations.
# Total iterations: 2739
# Convergence achieved after 2017 iterations.
# Total iterations: 2017
# Convergence achieved after 1738 iterations.
# Total iterations: 1738
# Convergence achieved after 2763 iterations.
# Total iterations: 2763
# Batch Size: 10, Avg Time: 4.06 sec, Avg Iterations: 2580.0
# Total iterations: 4000
# Total iterations: 4000
# Convergence achieved after 3757 iterations.
# Total iterations: 3757
# Convergence achieved after 3703 iterations.
# Total iterations: 3703
# Total iterations: 4000
# Total iterations: 4000
# Batch Size: 50, Avg Time: 6.27 sec, Avg Iterations: 3911.0
# Convergence achieved after 3698 iterations.
# Total iterations: 3698
# Convergence achieved after 3733 iterations.
# Total iterations: 3733
# Total iterations: 4000
# Convergence achieved after 3697 iterations.
# Total iterations: 3697
# Total iterations: 4000
# Total iterations: 4000
# Batch Size: 100, Avg Time: 6.12 sec, Avg Iterations: 3855.6666666666665
# Total iterations: 4000
# Total iterations: 4000
# Total iterations: 4000
# Total iterations: 4000
# Total iterations: 4000
# Total iterations: 4000
# Batch Size: 500, Avg Time: 6.49 sec, Avg Iterations: 4001.0

# %%
plt.figure(figsize=(10, 6))
plt.plot([r['batch_size'] for r in results], [r['avg_iterations'] for r in results], marker='o')
plt.xlabel('Batch Size')
plt.ylabel('Iterations to Convergence')
plt.title('Iterations to Convergence vs Batch Size')
plt.grid(True)
plt.show()

plt.figure(figsize=(10, 6))
plt.plot([r['batch_size'] for r in results], [r['avg_time'] for r in results], marker='o', color='red')
plt.xlabel('Batch Size')
plt.ylabel('Training Time (seconds)')
plt.title('Training Time vs Batch Size')
plt.grid(True)
plt.show()

# %%
В нашем случае оптимальный размер батча 1, так как модель чаще обновляется и получается малое количество итераций

# %% [markdown]
# ## Задание 7. Регуляризация (0.5 балла)
#
# В этом задании вам предстоит исследовать влияние регуляризации на работу различных методов градиентного спуска. Напомним, регуляризация - это добавка к функции потерь, которая штрафует за норму весов. Мы будем использовать l2 регуляризацию, таким образом функция потерь приобретает следующий вид:
#
# $$
#     Q(w) = \dfrac{1}{\ell} \sum\limits_{i=1}^{\ell} (a_w(x_i) - y_i)^2 + \dfrac{\mu}{2} \| w \|^2
# $$

# %% [markdown]
# Допишите класс **BaseDescentReg** в файле `descents.py`.

# %% [markdown]
# Найдите лучшие параметры обучения с регуляризацией аналогично 5 заданию. Вам предстоит исследовать, как настройка параметров обучения с включением регуляризации влияет на различные методы градиентного спуска. Основная цель — определить оптимальные значения для длины шага $\lambda$ и коэффициента регуляризации $\mu$, а затем сравнить результаты обучения с регуляризацией и без неё по нескольким критериям.
#
# Ваш план действий следующий:
#
# 1. **Выбор параметров для подбора**: Установите диапазон значений для длины шага $\lambda$ и коэффициента регуляризации $\mu$. Используйте логарифмическую сетку для обоих параметров, чтобы обеспечить широкий охват потенциально оптимальных значений.
#
# 2. **Оптимизация и сравнение методов градиентного спуска**:
#    - Произведите подбор параметров для каждого метода градиентного спуска, исследуя их влияние на процесс обучения.
#    - Замерьте и сравните ошибку и качество по метрике $R^2$ на обучающей и тестовой выборках, а также количество итераций до сходимости для моделей с регуляризацией и без неё.
#
# 3. **Визуализация результатов**:
#    - Постройте для каждого метода графики, отображающие значения функции потерь (MSE) с регуляризацией и без неё на протяжении процесса обучения.
#
# 4. **Анализ результатов**:
#    - Оцените, как регуляризация повлияла на сходимость методов.
#    - Сравните качество моделей на обучающей и тестовой выборках с учетом регуляризации и без неё.
#    - Проанализируйте, как изменения в длине шага и коэффициенте регуляризации отразились на итоговых результатах.
#
# 5. **Формулировка выводов**:
#    - Сделайте выводы о влиянии регуляризации на процесс обучения и качество модели. Как регуляризация влияет на переобучение и обобщающую способность модели.
#    - Рассмотрите, в каких случаях регуляризация приводит к улучшению результатов, и когда её вклад может быть минимальным или отрицательным.

# %%
#╰( ͡☉ ͜ʖ ͡☉ )つ──☆*:・ﾟ   ฅ^•ﻌ•^ฅ   ʕ•ᴥ•ʔ
# %autoreload 2

import numpy as np
import math
import matplotlib.pyplot as plt
from tqdm import tqdm

from linear_regression import LinearRegression  
from descents import LossFunction
descents = ["full", "stochastic", "momentum", "adam"]
lambda_values = np.logspace(-4, 1, num=6)  # Примеры длин шагов
mu_values = np.logspace(-6, 1, num=8)  # Примеры коэффициентов регуляризации
results = []
for descent_name in tqdm(descents, desc=f"Overall Progress", leave=False):
    loss_histories = []
    convergence_iterations = []

    for mu in mu_values:
        for lr in learning_rates:
            descent_config = {
                'descent_name': descent_name,
                'regularized': True,
                'kwargs': {
                    'dimension': x_train.shape[1],
                    'lambda_': lr,
                    'mu': mu,
                    'loss_function': LossFunction.MSE
                }
            }
            model = LinearRegression(descent_config=descent_config, max_iter=5000)
            
            model.fit(x_train, y_train)
            
            train_loss = model.calc_loss(x_train, y_train)
            val_loss = model.calc_loss(x_val, y_val)

            r2_train = model.score(x_train, y_train)
            r2_val = model.score(x_val, y_val)
    
            if not math.isnan(train_loss) and not math.isnan(val_loss):
                loss_histories.append((lr, mu, model.loss_history, train_loss, val_loss, r2_train, r2_val))
                convergence_iterations.append(len(model.loss_history))
    
            print(f"Descent name: {descent_name}")
            print(f"Mu: {mu}")
            print(f"Learning rate: {lr}")
            print(f"Train Loss: {train_loss}")
            print(f"Validation Loss: {val_loss}")
            print(f"R^2 on training set: {r2_train}")
            print(f"R^2 on training set: {r2_val}")
        
    
    results.append({
        'descent_name': descent_name,
        'loss_histories': loss_histories,
        'convergence_iterations': convergence_iterations
    })
# Out:
# Overall Progress:   0%|          | 0/4 [00:00<?, ?it/s]
# Convergence achieved after 283 iterations.
# Total iterations: 283
# Descent name: full
# Mu: 1e-06
# Learning rate: 0.0001
# Train Loss: 24.680801309479996
# Validation Loss: 24.435576274636677
# R^2 on training set: -18.978369442021116
# R^2 on training set: -18.79507239124445
# Total iterations: 5000
# Descent name: full
# Mu: 1e-06
# Learning rate: 0.001
# Train Loss: 7.599473076275551
# Validation Loss: 7.551897242201521
# R^2 on training set: -5.15154584240379
# R^2 on training set: -5.1177338696851
# Convergence achieved after 2563 iterations.
# Total iterations: 2563
# Descent name: full
# Mu: 1e-06
# Learning rate: 0.01
# Train Loss: 0.6337128982152331
# Validation Loss: 0.6360138739675244
# R^2 on training set: 0.4870283893151037
# R^2 on training set: 0.48477005266739237
# Convergence achieved after 3291 iterations.
# Total iterations: 3291
# Descent name: full
# Mu: 1e-06
# Learning rate: 0.1
# Train Loss: 0.3341964397846485
# Validation Loss: 0.34608130892780103
# R^2 on training set: 0.7294779915568899
# R^2 on training set: 0.7196421935588537
# Convergence achieved after 3231 iterations.
# Total iterations: 3231
# Descent name: full
# Mu: 1e-06
# Learning rate: 1.0
# Train Loss: 0.2969039148350914
# Validation Loss: 0.3106275504833024
# R^2 on training set: 0.7596651735501206
# R^2 on training set: 0.7483630105783812
# Training stopped due to NaN values in weights.
# Total iterations: 548
# Descent name: full
# Mu: 1e-06
# Learning rate: 10.0
# Train Loss: nan
# Validation Loss: nan
# R^2 on training set: 1.0
# R^2 on training set: 1.0
# Convergence achieved after 285 iterations.
# Total iterations: 285
# Descent name: full
# Mu: 1e-05
# Learning rate: 0.0001
# Train Loss: 24.31848795640195
# Validation Loss: 24.020922240412656
# R^2 on training set: -18.685087634400457
# R^2 on training set: -18.459164347475262
# Convergence achieved after 4582 iterations.
# Total iterations: 4582
# Descent name: full
# Mu: 1e-05
# Learning rate: 0.001
# Train Loss: 5.079856547886058
# Validation Loss: 5.065012255387146
# R^2 on training set: -3.111991728046367
# R^2 on training set: -3.1031274700076477
# Convergence achieved after 2411 iterations.
# Total iterations: 2411
# Descent name: full
# Mu: 1e-05
# Learning rate: 0.01
# Train Loss: 0.6124906847967964
# Validation Loss: 0.6244393514811503
# R^2 on training set: 0.5042071354479569
# R^2 on training set: 0.494146484306931
# Convergence achieved after 3060 iterations.
# Total iterations: 3060
# Descent name: full
# Mu: 1e-05
# Learning rate: 0.1
# Train Loss: 0.3343512313621456
# Validation Loss: 0.3482540826571849
# R^2 on training set: 0.7293526924110894
# R^2 on training set: 0.7178820462728005
# Convergence achieved after 3561 iterations.
# Total iterations: 3561
# Descent name: full
# Mu: 1e-05
# Learning rate: 1.0
# Train Loss: 0.29660685685067745
# Validation Loss: 0.3098431657474281
# R^2 on training set: 0.7599056330912801
# R^2 on training set: 0.748998434619734
# Training stopped due to NaN values in weights.
# Total iterations: 549
# Descent name: full
# Mu: 1e-05
# Learning rate: 10.0
# Train Loss: nan
# Validation Loss: nan
# R^2 on training set: 1.0
# R^2 on training set: 1.0
# Convergence achieved after 410 iterations.
# Total iterations: 410
# Descent name: full
# Mu: 0.0001
# Learning rate: 0.0001
# Train Loss: 32.37086226838163
# Validation Loss: 32.20194742666695
# R^2 on training set: -25.20324346220085
# R^2 on training set: -25.08654992563289
# Total iterations: 5000
# Descent name: full
# Mu: 0.0001
# Learning rate: 0.001
# Train Loss: 6.7810792251810925
# Validation Loss: 6.7673633056174065
# R^2 on training set: -4.489080531767245
# R^2 on training set: -4.48218896198468
# Convergence achieved after 2361 iterations.
# Total iterations: 2361
# Descent name: full
# Mu: 0.0001
# Learning rate: 0.01
# Train Loss: 0.6295222488590283
# Validation Loss: 0.6504869351129238
# R^2 on training set: 0.49042059445424846
# R^2 on training set: 0.4730455371545964
# Convergence achieved after 2719 iterations.
# Total iterations: 2719
# Descent name: full
# Mu: 0.0001
# Learning rate: 0.1
# Train Loss: 0.32496433411229875
# Validation Loss: 0.34053251363322584
# R^2 on training set: 0.7369511045866171
# R^2 on training set: 0.7241372299478388
# Convergence achieved after 3371 iterations.
# Total iterations: 3371
# Descent name: full
# Mu: 0.0001
# Learning rate: 1.0
# Train Loss: 0.2962563595764846
# Validation Loss: 0.30986179318279417
# R^2 on training set: 0.7601893501369481
# R^2 on training set: 0.7489833446776188
# Training stopped due to NaN values in weights.
# Total iterations: 549
# Descent name: full
# Mu: 0.0001
# Learning rate: 10.0
# Train Loss: nan
# Validation Loss: nan
# R^2 on training set: 1.0
# R^2 on training set: 1.0
# Convergence achieved after 356 iterations.
# Total iterations: 356
# Descent name: full
# Mu: 0.001
# Learning rate: 0.0001
# Train Loss: 28.910587315350888
# Validation Loss: 28.619782748975286
# R^2 on training set: -22.40225452688346
# R^2 on training set: -22.184665872836202
# Total iterations: 5000
# Descent name: full
# Mu: 0.001
# Learning rate: 0.001
# Train Loss: 5.696861103537213
# Validation Loss: 5.64429072020295
# R^2 on training set: -3.6114384358594602
# R^2 on training set: -3.572396498772892
# Convergence achieved after 2914 iterations.
# Total iterations: 2914
# Descent name: full
# Mu: 0.001
# Learning rate: 0.01
# Train Loss: 0.626543265980674
# Validation Loss: 0.6432081735709954
# R^2 on training set: 0.492831991870359
# R^2 on training set: 0.47894200589434255
# Convergence achieved after 3255 iterations.
# Total iterations: 3255
# Descent name: full
# Mu: 0.001
# Learning rate: 0.1
# Train Loss: 0.33096588540602223
# Validation Loss: 0.3446354093213834
# R^2 on training set: 0.7320930285676186
# R^2 on training set: 0.7208135057087217
# Convergence achieved after 4310 iterations.
# Total iterations: 4310
# Descent name: full
# Mu: 0.001
# Learning rate: 1.0
# Train Loss: 0.2964480102180391
# Validation Loss: 0.3105188812155297
# R^2 on training set: 0.7600342146827639
# R^2 on training set: 0.7484510427163625
# Training stopped due to NaN values in weights.
# Total iterations: 548
# Descent name: full
# Mu: 0.001
# Learning rate: 10.0
# Train Loss: nan
# Validation Loss: nan
# R^2 on training set: 1.0
# R^2 on training set: 1.0
# Convergence achieved after 334 iterations.
# Total iterations: 334
# Descent name: full
# Mu: 0.01
# Learning rate: 0.0001
# Train Loss: 27.98271701715557
# Validation Loss: 27.671705179747967
# R^2 on training set: -21.651171311262573
# R^2 on training set: -21.4166355262448
# Total iterations: 5000
# Descent name: full
# Mu: 0.01
# Learning rate: 0.001
# Train Loss: 7.661764152096371
# Validation Loss: 7.6582932065461025
# R^2 on training set: -5.201968602592345
# R^2 on training set: -5.203924422044748
# Convergence achieved after 2306 iterations.
# Total iterations: 2306
# Descent name: full
# Mu: 0.01
# Learning rate: 0.01
# Train Loss: 0.6344717087690332
# Validation Loss: 0.656258172919983
# R^2 on training set: 0.4864141548990396
# R^2 on training set: 0.4683703017971882
# Convergence achieved after 4825 iterations.
# Total iterations: 4825
# Descent name: full
# Mu: 0.01
# Learning rate: 0.1
# Train Loss: 0.33067470679408817
# Validation Loss: 0.34635467399900244
# R^2 on training set: 0.7323287289328495
# R^2 on training set: 0.71942074261729
# Convergence achieved after 4074 iterations.
# Total iterations: 4074
# Descent name: full
# Mu: 0.01
# Learning rate: 1.0
# Train Loss: 0.3085069310014015
# Validation Loss: 0.3232368105258052
# R^2 on training set: 0.750272879486992
# R^2 on training set: 0.7381483460034168
# Training stopped due to NaN values in weights.
# Total iterations: 545
# Descent name: full
# Mu: 0.01
# Learning rate: 10.0
# Train Loss: nan
# Validation Loss: nan
# R^2 on training set: 1.0
# R^2 on training set: 1.0
# Convergence achieved after 309 iterations.
# Total iterations: 309
# Descent name: full
# Mu: 0.1
# Learning rate: 0.0001
# Train Loss: 26.21492797584071
# Validation Loss: 25.951295109453834
# R^2 on training set: -20.22019902960578
# R^2 on training set: -20.022944561016903
# Total iterations: 5000
# Descent name: full
# Mu: 0.1
# Learning rate: 0.001
# Train Loss: 6.719145011579067
# Validation Loss: 6.71935434894582
# R^2 on training set: -4.438946640856375
# R^2 on training set: -4.443297275451034
# Convergence achieved after 4144 iterations.
# Total iterations: 4144
# Descent name: full
# Mu: 0.1
# Learning rate: 0.01
# Train Loss: 0.5822084737305112
# Validation Loss: 0.6023680514901041
# R^2 on training set: 0.528719678319534
# R^2 on training set: 0.5120262746659219
# Convergence achieved after 4019 iterations.
# Total iterations: 4019
# Descent name: full
# Mu: 0.1
# Learning rate: 0.1
# Train Loss: 0.5002299052715987
# Validation Loss: 0.521081419480456
# R^2 on training set: 0.5950788741358826
# R^2 on training set: 0.5778759500321458
# Convergence achieved after 273 iterations.
# Total iterations: 273
# Descent name: full
# Mu: 0.1
# Learning rate: 1.0
# Train Loss: 0.495550624684888
# Validation Loss: 0.5162313626341377
# R^2 on training set: 0.598866611621062
# R^2 on training set: 0.5818049437786192
# Training stopped due to NaN values in weights.
# Total iterations: 518
# Descent name: full
# Mu: 0.1
# Learning rate: 10.0
# Train Loss: nan
# Validation Loss: nan
# R^2 on training set: 1.0
# R^2 on training set: 1.0
# Convergence achieved after 350 iterations.
# Total iterations: 350
# Descent name: full
# Mu: 1.0
# Learning rate: 0.0001
# Train Loss: 31.69232022721353
# Validation Loss: 31.376055160919876
# R^2 on training set: -24.653984002979307
# R^2 on training set: -24.417500953589556
# Total iterations: 5000
# Descent name: full
# Mu: 1.0
# Learning rate: 0.001
# Train Loss: 9.504061798021985
# Validation Loss: 9.45831630983643
# R^2 on training set: -6.693253368064297
# R^2 on training set: -6.662109292950737
# Convergence achieved after 4095 iterations.
# Total iterations: 4095
# Descent name: full
# Mu: 1.0
# Learning rate: 0.01
# Train Loss: 4.710049480948008
# Validation Loss: 4.739844187512653
# R^2 on training set: -2.8126439835012675
# R^2 on training set: -2.8397113192873644
# Convergence achieved after 295 iterations.
# Total iterations: 295
# Descent name: full
# Mu: 1.0
# Learning rate: 0.1
# Train Loss: 4.725810572557253
# Validation Loss: 4.758479644364964
# R^2 on training set: -2.8254021150963746
# R^2 on training set: -2.8548077595468193
# Convergence achieved after 2063 iterations.
# Total iterations: 2063
# Descent name: full
# Mu: 1.0
# Learning rate: 1.0
# Train Loss: 4.732724006418076
# Validation Loss: 4.76488935925769
# R^2 on training set: -2.8309983327415216
# R^2 on training set: -2.8600002202804116
# Training stopped due to NaN values in weights.
# Total iterations: 385
# Descent name: full
# Mu: 1.0
# Learning rate: 10.0
# Train Loss: nan
# Validation Loss: nan
# R^2 on training set: 1.0
# R^2 on training set: 1.0
# Convergence achieved after 4689 iterations.
# Total iterations: 4689
# Descent name: full
# Mu: 10.0
# Learning rate: 0.0001
# Train Loss: 29.525741238598968
# Validation Loss: 29.276889316483622
# R^2 on training set: -22.900203203194806
# R^2 on training set: -22.71698284896952
# Convergence achieved after 4633 iterations.
# Total iterations: 4633
# Descent name: full
# Mu: 10.0
# Learning rate: 0.001
# Train Loss: 39.85368841350848
# Validation Loss: 39.73285333427191
# R^2 on training set: -31.260367107547708
# R^2 on training set: -31.1872788766184
# Convergence achieved after 256 iterations.
# Total iterations: 256
# Descent name: full
# Mu: 10.0
# Learning rate: 0.01
# Train Loss: 40.11350134855414
# Validation Loss: 40.01204197690223
# R^2 on training set: -31.470677896774973
# R^2 on training set: -31.413447448604032
# Convergence achieved after 3727 iterations.
# Total iterations: 3727
# Descent name: full
# Mu: 10.0
# Learning rate: 0.1
# Train Loss: 40.063033089942586
# Validation Loss: 39.95110072466051
# R^2 on training set: -31.42982535301052
# R^2 on training set: -31.36407940889915
# Total iterations: 5000
# Descent name: full
# Mu: 10.0
# Learning rate: 1.0
# Train Loss: 3.5547163194361326e+78
# Validation Loss: 4.062218777162948e+78
# R^2 on training set: -2.877436392796474e+78
# R^2 on training set: -3.2907721863911176e+78
# Overall Progress:  25%|██▌       | 1/4 [06:51<20:34, 411.49s/it]
# Training stopped due to NaN values in weights.
# Total iterations: 209
# Descent name: full
# Mu: 10.0
# Learning rate: 10.0
# Train Loss: nan
# Validation Loss: nan
# R^2 on training set: 1.0
# R^2 on training set: 1.0
# Convergence achieved after 363 iterations.
# Total iterations: 363
# Descent name: stochastic
# Mu: 1e-06
# Learning rate: 0.0001
# Train Loss: 33.84223208785942
# Validation Loss: 33.52439245857414
# R^2 on training set: -26.39427326187256
# R^2 on training set: -26.157852474254028
# Convergence achieved after 3988 iterations.
# Total iterations: 3988
# Descent name: stochastic
# Mu: 1e-06
# Learning rate: 0.001
# Train Loss: 5.4417139216962065
# Validation Loss: 5.441215652726616
# R^2 on training set: -3.4049044341067605
# R^2 on training set: -3.407886948583834
# Convergence achieved after 1473 iterations.
# Total iterations: 1473
# Descent name: stochastic
# Mu: 1e-06
# Learning rate: 0.01
# Train Loss: 0.529500609994858
# Validation Loss: 0.5440926356538386
# R^2 on training set: 0.5713851153532221
# R^2 on training set: 0.5592347408033098
# Total iterations: 5000
# Descent name: stochastic
# Mu: 1e-06
# Learning rate: 0.1
# Train Loss: 0.31763359271862185
# Validation Loss: 0.3310177545512579
# R^2 on training set: 0.742885120180776
# R^2 on training set: 0.7318450630963577
# Total iterations: 5000
# Descent name: stochastic
# Mu: 1e-06
# Learning rate: 1.0
# Train Loss: 65.80143669749765
# Validation Loss: 66.15788140075718
# R^2 on training set: -52.26429217893459
# R^2 on training set: -52.59399086235895
# Training stopped due to NaN values in weights.
# Total iterations: 563
# Descent name: stochastic
# Mu: 1e-06
# Learning rate: 10.0
# Train Loss: nan
# Validation Loss: nan
# R^2 on training set: 1.0
# R^2 on training set: 1.0
# Convergence achieved after 261 iterations.
# Total iterations: 261
# Descent name: stochastic
# Mu: 1e-05
# Learning rate: 0.0001
# Train Loss: 27.123770290187682
# Validation Loss: 26.80202099292778
# R^2 on training set: -20.955879662211135
# R^2 on training set: -20.71211105577036
# Convergence achieved after 4384 iterations.
# Total iterations: 4384
# Descent name: stochastic
# Mu: 1e-05
# Learning rate: 0.001
# Train Loss: 7.230417413972694
# Validation Loss: 7.200421345678576
# R^2 on training set: -4.852806337405457
# R^2 on training set: -4.833005949326172
# Convergence achieved after 1490 iterations.
# Total iterations: 1490
# Descent name: stochastic
# Mu: 1e-05
# Learning rate: 0.01
# Train Loss: 0.5065158098291801
# Validation Loss: 0.5247823249263216
# R^2 on training set: 0.589990622666494
# R^2 on training set: 0.5748778749963588
# Total iterations: 5000
# Descent name: stochastic
# Mu: 1e-05
# Learning rate: 0.1
# Train Loss: 0.3175502960189166
# Validation Loss: 0.33266728822084146
# R^2 on training set: 0.7429525463643567
# R^2 on training set: 0.730508788558192
# Total iterations: 5000
# Descent name: stochastic
# Mu: 1e-05
# Learning rate: 1.0
# Train Loss: 33.006148354088246
# Validation Loss: 33.52129632342146
# R^2 on training set: -25.717488521041272
# R^2 on training set: -26.155344318981097
# Training stopped due to NaN values in weights.
# Total iterations: 563
# Descent name: stochastic
# Mu: 1e-05
# Learning rate: 10.0
# Train Loss: nan
# Validation Loss: nan
# R^2 on training set: 1.0
# R^2 on training set: 1.0
# Convergence achieved after 333 iterations.
# Total iterations: 333
# Descent name: stochastic
# Mu: 0.0001
# Learning rate: 0.0001
# Train Loss: 36.16976648698031
# Validation Loss: 35.8441575711526
# R^2 on training set: -28.27834264566476
# R^2 on training set: -28.037076349233285
# Convergence achieved after 4205 iterations.
# Total iterations: 4205
# Descent name: stochastic
# Mu: 0.0001
# Learning rate: 0.001
# Train Loss: 7.290626643768642
# Validation Loss: 7.19210157530107
# R^2 on training set: -4.901543905590528
# R^2 on training set: -4.826266167335755
# Convergence achieved after 1940 iterations.
# Total iterations: 1940
# Descent name: stochastic
# Mu: 0.0001
# Learning rate: 0.01
# Train Loss: 0.6307384105242136
# Validation Loss: 0.6404995372768646
# R^2 on training set: 0.48943614801170265
# R^2 on training set: 0.4811362513224532
# Total iterations: 5000
# Descent name: stochastic
# Mu: 0.0001
# Learning rate: 0.1
# Train Loss: 0.33036684663921
# Validation Loss: 0.3453759342243737
# R^2 on training set: 0.7325779325074624
# R^2 on training set: 0.7202136121806355
# Total iterations: 5000
# Descent name: stochastic
# Mu: 0.0001
# Learning rate: 1.0
# Train Loss: 29.038287412168884
# Validation Loss: 30.504597477833116
# R^2 on training set: -22.505623930494835
# R^2 on training set: -23.7115397874306
# Training stopped due to NaN values in weights.
# Total iterations: 563
# Descent name: stochastic
# Mu: 0.0001
# Learning rate: 10.0
# Train Loss: nan
# Validation Loss: nan
# R^2 on training set: 1.0
# R^2 on training set: 1.0
# Convergence achieved after 325 iterations.
# Total iterations: 325
# Descent name: stochastic
# Mu: 0.001
# Learning rate: 0.0001
# Train Loss: 33.09511729974987
# Validation Loss: 32.71839407140509
# R^2 on training set: -25.789506217833488
# R^2 on training set: -25.504919380230863
# Convergence achieved after 3738 iterations.
# Total iterations: 3738
# Descent name: stochastic
# Mu: 0.001
# Learning rate: 0.001
# Train Loss: 6.980704318059291
# Validation Loss: 6.938148985903323
# R^2 on training set: -4.650671065454113
# R^2 on training set: -4.620541127968043
# Convergence achieved after 2053 iterations.
# Total iterations: 2053
# Descent name: stochastic
# Mu: 0.001
# Learning rate: 0.01
# Train Loss: 0.6020073042721765
# Validation Loss: 0.6197981097762799
# R^2 on training set: 0.512693117993495
# R^2 on training set: 0.49790631851344136
# Total iterations: 5000
# Descent name: stochastic
# Mu: 0.001
# Learning rate: 0.1
# Train Loss: 0.3319122971170781
# Validation Loss: 0.3454597356945138
# R^2 on training set: 0.7313269366336235
# R^2 on training set: 0.7201457252542429
# Total iterations: 5000
# Descent name: stochastic
# Mu: 0.001
# Learning rate: 1.0
# Train Loss: 29.699081749019527
# Validation Loss: 32.27141341980517
# R^2 on training set: -23.040517154635282
# R^2 on training set: -25.142823792369075
# Training stopped due to NaN values in weights.
# Total iterations: 563
# Descent name: stochastic
# Mu: 0.001
# Learning rate: 10.0
# Train Loss: nan
# Validation Loss: nan
# R^2 on training set: 1.0
# R^2 on training set: 1.0
# Convergence achieved after 296 iterations.
# Total iterations: 296
# Descent name: stochastic
# Mu: 0.01
# Learning rate: 0.0001
# Train Loss: 31.04811684748712
# Validation Loss: 30.72369994320292
# R^2 on training set: -24.132520661712935
# R^2 on training set: -23.88903300937672
# Convergence achieved after 4684 iterations.
# Total iterations: 4684
# Descent name: stochastic
# Mu: 0.01
# Learning rate: 0.001
# Train Loss: 7.879942704275386
# Validation Loss: 7.836667102608942
# R^2 on training set: -5.378577605886067
# R^2 on training set: -5.348423743263425
# Convergence achieved after 1883 iterations.
# Total iterations: 1883
# Descent name: stochastic
# Mu: 0.01
# Learning rate: 0.01
# Train Loss: 0.6996751560404553
# Validation Loss: 0.718009269542795
# R^2 on training set: 0.4336339172500514
# R^2 on training set: 0.418346213388188
# Total iterations: 5000
# Descent name: stochastic
# Mu: 0.01
# Learning rate: 0.1
# Train Loss: 0.32843398304210275
# Validation Loss: 0.3444699264903985
# R^2 on training set: 0.7341425276978629
# R^2 on training set: 0.7209475620772738
# Total iterations: 5000
# Descent name: stochastic
# Mu: 0.01
# Learning rate: 1.0
# Train Loss: 1.7522472035442593
# Validation Loss: 1.9564893111470707
# R^2 on training set: -0.41839162947716924
# R^2 on training set: -0.5849369424142259
# Training stopped due to NaN values in weights.
# Total iterations: 557
# Descent name: stochastic
# Mu: 0.01
# Learning rate: 10.0
# Train Loss: nan
# Validation Loss: nan
# R^2 on training set: 1.0
# R^2 on training set: 1.0
# Convergence achieved after 424 iterations.
# Total iterations: 424
# Descent name: stochastic
# Mu: 0.1
# Learning rate: 0.0001
# Train Loss: 38.66494217884127
# Validation Loss: 38.50363315560234
# R^2 on training set: -30.298112634883122
# R^2 on training set: -30.191497064556167
# Convergence achieved after 4187 iterations.
# Total iterations: 4187
# Descent name: stochastic
# Mu: 0.1
# Learning rate: 0.001
# Train Loss: 9.416901713376859
# Validation Loss: 9.329203680115201
# R^2 on training set: -6.622699890087497
# R^2 on training set: -6.557516144697118
# Convergence achieved after 3970 iterations.
# Total iterations: 3970
# Descent name: stochastic
# Mu: 0.1
# Learning rate: 0.01
# Train Loss: 0.6506424871127582
# Validation Loss: 0.6689304080815366
# R^2 on training set: 0.4733243941629536
# R^2 on training set: 0.45810462156266074
# Total iterations: 5000
# Descent name: stochastic
# Mu: 0.1
# Learning rate: 0.1
# Train Loss: 0.49581906338287285
# Validation Loss: 0.5161517158087281
# R^2 on training set: 0.5986493185350868
# R^2 on training set: 0.5818694650592715
# Total iterations: 5000
# Descent name: stochastic
# Mu: 0.1
# Learning rate: 1.0
# Train Loss: 32.23492862695393
# Validation Loss: 36.728054689629474
# R^2 on training set: -25.093209250831926
# R^2 on training set: -28.75311460632253
# Training stopped due to NaN values in weights.
# Total iterations: 531
# Descent name: stochastic
# Mu: 0.1
# Learning rate: 10.0
# Train Loss: nan
# Validation Loss: nan
# R^2 on training set: 1.0
# R^2 on training set: 1.0
# Convergence achieved after 360 iterations.
# Total iterations: 360
# Descent name: stochastic
# Mu: 1.0
# Learning rate: 0.0001
# Train Loss: 39.914379706549035
# Validation Loss: 39.423269646410034
# R^2 on training set: -31.30949489149095
# R^2 on training set: -30.93648751227742
# Total iterations: 5000
# Descent name: stochastic
# Mu: 1.0
# Learning rate: 0.001
# Train Loss: 10.095944170127103
# Validation Loss: 10.046626359728224
# R^2 on training set: -7.172364420734775
# R^2 on training set: -7.138694739318641
# Total iterations: 5000
# Descent name: stochastic
# Mu: 1.0
# Learning rate: 0.01
# Train Loss: 4.695598120562636
# Validation Loss: 4.72792394576701
# R^2 on training set: -2.8009460401039488
# R^2 on training set: -2.8300548231350287
# Total iterations: 5000
# Descent name: stochastic
# Mu: 1.0
# Learning rate: 0.1
# Train Loss: 4.75720416067298
# Validation Loss: 4.791145492249354
# R^2 on training set: -2.85081428440247
# R^2 on training set: -2.8812701116651143
# Total iterations: 5000
# Descent name: stochastic
# Mu: 1.0
# Learning rate: 1.0
# Train Loss: 61362.678776741785
# Validation Loss: 70112.45152481955
# R^2 on training set: -49670.25058791882
# R^2 on training set: -56796.55770286438
# Training stopped due to NaN values in weights.
# Total iterations: 392
# Descent name: stochastic
# Mu: 1.0
# Learning rate: 10.0
# Train Loss: nan
# Validation Loss: nan
# R^2 on training set: 1.0
# R^2 on training set: 1.0
# Convergence achieved after 4463 iterations.
# Total iterations: 4463
# Descent name: stochastic
# Mu: 10.0
# Learning rate: 0.0001
# Train Loss: 30.884506057545455
# Validation Loss: 30.698738900514368
# R^2 on training set: -24.000082627583954
# R^2 on training set: -23.868812260685242
# Convergence achieved after 4181 iterations.
# Total iterations: 4181
# Descent name: stochastic
# Mu: 10.0
# Learning rate: 0.001
# Train Loss: 40.090570389038064
# Validation Loss: 39.9755199006848
# R^2 on training set: -31.452115971854965
# R^2 on training set: -31.383861195573736
# Total iterations: 5000
# Descent name: stochastic
# Mu: 10.0
# Learning rate: 0.01
# Train Loss: 40.083534500472666
# Validation Loss: 39.98522210924192
# R^2 on training set: -31.446420630794123
# R^2 on training set: -31.391720880100287
# Total iterations: 5000
# Descent name: stochastic
# Mu: 10.0
# Learning rate: 0.1
# Train Loss: 40.079092917316096
# Validation Loss: 39.96430373058491
# R^2 on training set: -31.44282530225933
# R^2 on training set: -31.374775062446183
# Total iterations: 5000
# Descent name: stochastic
# Mu: 10.0
# Learning rate: 1.0
# Train Loss: 5.5396986892276215e+109
# Validation Loss: 6.329699795157375e+109
# R^2 on training set: -4.484220168668476e+109
# R^2 on training set: -5.127641118496536e+109
# Overall Progress:  50%|█████     | 2/4 [10:30<09:56, 298.13s/it]
# Training stopped due to NaN values in weights.
# Total iterations: 212
# Descent name: stochastic
# Mu: 10.0
# Learning rate: 10.0
# Train Loss: nan
# Validation Loss: nan
# R^2 on training set: 1.0
# R^2 on training set: 1.0
# Total iterations: 5000
# Descent name: momentum
# Mu: 1e-06
# Learning rate: 0.0001
# Train Loss: 0.38810544309568956
# Validation Loss: 0.40109424423225015
# R^2 on training set: 0.6858402680124184
# R^2 on training set: 0.6750766378065733
# Total iterations: 5000
# Descent name: momentum
# Mu: 1e-06
# Learning rate: 0.001
# Train Loss: 0.29947476757185976
# Validation Loss: 0.3135743658332824
# R^2 on training set: 0.7575841452596631
# R^2 on training set: 0.7459758181291065
# Total iterations: 5000
# Descent name: momentum
# Mu: 1e-06
# Learning rate: 0.01
# Train Loss: 0.2942232443892369
# Validation Loss: 0.3074127836301613
# R^2 on training set: 0.7618350959869185
# R^2 on training set: 0.7509672684793889
# Convergence achieved after 2526 iterations.
# Total iterations: 2526
# Descent name: momentum
# Mu: 1e-06
# Learning rate: 0.1
# Train Loss: 0.2939484430941716
# Validation Loss: 0.3067246021119235
# R^2 on training set: 0.7620575394046631
# R^2 on training set: 0.7515247590340919
# Training stopped due to NaN values in weights.
# Total iterations: 460
# Descent name: momentum
# Mu: 1e-06
# Learning rate: 1.0
# Train Loss: nan
# Validation Loss: nan
# R^2 on training set: 1.0
# R^2 on training set: 1.0
# Training stopped due to NaN values in weights.
# Total iterations: 169
# Descent name: momentum
# Mu: 1e-06
# Learning rate: 10.0
# Train Loss: nan
# Validation Loss: nan
# R^2 on training set: 1.0
# R^2 on training set: 1.0
# Total iterations: 5000
# Descent name: momentum
# Mu: 1e-05
# Learning rate: 0.0001
# Train Loss: 0.37486390084636784
# Validation Loss: 0.3894250770666041
# R^2 on training set: 0.6965588998640296
# R^2 on training set: 0.6845297403728205
# Total iterations: 5000
# Descent name: momentum
# Mu: 1e-05
# Learning rate: 0.001
# Train Loss: 0.3004758154552687
# Validation Loss: 0.31378742115955494
# R^2 on training set: 0.7567738269805635
# R^2 on training set: 0.745803223648031
# Total iterations: 5000
# Descent name: momentum
# Mu: 1e-05
# Learning rate: 0.01
# Train Loss: 0.29416560571457273
# Validation Loss: 0.30709966993637605
# R^2 on training set: 0.7618817527677153
# R^2 on training set: 0.751220919474377
# Convergence achieved after 3538 iterations.
# Total iterations: 3538
# Descent name: momentum
# Mu: 1e-05
# Learning rate: 0.1
# Train Loss: 0.2939447181809236
# Validation Loss: 0.3067046808775102
# R^2 on training set: 0.762060554610372
# R^2 on training set: 0.7515408970728638
# Training stopped due to NaN values in weights.
# Total iterations: 460
# Descent name: momentum
# Mu: 1e-05
# Learning rate: 1.0
# Train Loss: nan
# Validation Loss: nan
# R^2 on training set: 1.0
# R^2 on training set: 1.0
# Training stopped due to NaN values in weights.
# Total iterations: 169
# Descent name: momentum
# Mu: 1e-05
# Learning rate: 10.0
# Train Loss: nan
# Validation Loss: nan
# R^2 on training set: 1.0
# R^2 on training set: 1.0
# Convergence achieved after 4676 iterations.
# Total iterations: 4676
# Descent name: momentum
# Mu: 0.0001
# Learning rate: 0.0001
# Train Loss: 0.34887798527362357
# Validation Loss: 0.36224668101478563
# R^2 on training set: 0.7175937202125101
# R^2 on training set: 0.7065467499688693
# Total iterations: 5000
# Descent name: momentum
# Mu: 0.0001
# Learning rate: 0.001
# Train Loss: 0.3014802926558293
# Validation Loss: 0.3151142384210505
# R^2 on training set: 0.7559607327719415
# R^2 on training set: 0.7447283791898498
# Total iterations: 5000
# Descent name: momentum
# Mu: 0.0001
# Learning rate: 0.01
# Train Loss: 0.294311210709685
# Validation Loss: 0.3072874359314186
# R^2 on training set: 0.7617638898852068
# R^2 on training set: 0.7510688116860151
# Total iterations: 5000
# Descent name: momentum
# Mu: 0.0001
# Learning rate: 0.1
# Train Loss: 0.29395724567080883
# Validation Loss: 0.3068238978032023
# R^2 on training set: 0.7620504139825225
# R^2 on training set: 0.7514443203583303
# Training stopped due to NaN values in weights.
# Total iterations: 460
# Descent name: momentum
# Mu: 0.0001
# Learning rate: 1.0
# Train Loss: nan
# Validation Loss: nan
# R^2 on training set: 1.0
# R^2 on training set: 1.0
# Training stopped due to NaN values in weights.
# Total iterations: 169
# Descent name: momentum
# Mu: 0.0001
# Learning rate: 10.0
# Train Loss: nan
# Validation Loss: nan
# R^2 on training set: 1.0
# R^2 on training set: 1.0
# Convergence achieved after 4718 iterations.
# Total iterations: 4718
# Descent name: momentum
# Mu: 0.001
# Learning rate: 0.0001
# Train Loss: 0.3575869750605592
# Validation Loss: 0.3676115650385524
# R^2 on training set: 0.7105440538241115
# R^2 on training set: 0.7022006986857932
# Total iterations: 5000
# Descent name: momentum
# Mu: 0.001
# Learning rate: 0.001
# Train Loss: 0.30044059524179195
# Validation Loss: 0.3136033418697101
# R^2 on training set: 0.7568023366884875
# R^2 on training set: 0.7459523448648687
# Total iterations: 5000
# Descent name: momentum
# Mu: 0.001
# Learning rate: 0.01
# Train Loss: 0.29489187741173645
# Validation Loss: 0.30833830741440216
# R^2 on training set: 0.7612938575815227
# R^2 on training set: 0.7502175087805402
# Convergence achieved after 2169 iterations.
# Total iterations: 2169
# Descent name: momentum
# Mu: 0.001
# Learning rate: 0.1
# Train Loss: 0.2948510560548913
# Validation Loss: 0.3082640245809147
# R^2 on training set: 0.7613269012472429
# R^2 on training set: 0.750277684732594
# Training stopped due to NaN values in weights.
# Total iterations: 460
# Descent name: momentum
# Mu: 0.001
# Learning rate: 1.0
# Train Loss: nan
# Validation Loss: nan
# R^2 on training set: 1.0
# R^2 on training set: 1.0
# Training stopped due to NaN values in weights.
# Total iterations: 169
# Descent name: momentum
# Mu: 0.001
# Learning rate: 10.0
# Train Loss: nan
# Validation Loss: nan
# R^2 on training set: 1.0
# R^2 on training set: 1.0
# Total iterations: 5000
# Descent name: momentum
# Mu: 0.01
# Learning rate: 0.0001
# Train Loss: 0.3863148144363362
# Validation Loss: 0.3968482474961999
# R^2 on training set: 0.6872897282808048
# R^2 on training set: 0.6785162871039114
# Total iterations: 5000
# Descent name: momentum
# Mu: 0.01
# Learning rate: 0.001
# Train Loss: 0.3101261050761736
# Validation Loss: 0.3247232096042147
# R^2 on training set: 0.7489622065695647
# R^2 on training set: 0.7369442255427942
# Convergence achieved after 2460 iterations.
# Total iterations: 2460
# Descent name: momentum
# Mu: 0.01
# Learning rate: 0.01
# Train Loss: 0.3081812920533241
# Validation Loss: 0.3228429954311409
# R^2 on training set: 0.7505364744622047
# R^2 on training set: 0.7384673725825336
# Convergence achieved after 387 iterations.
# Total iterations: 387
# Descent name: momentum
# Mu: 0.01
# Learning rate: 0.1
# Train Loss: 0.308142597382579
# Validation Loss: 0.3228044187035991
# R^2 on training set: 0.7505677966392236
# R^2 on training set: 0.7384986232927981
# Training stopped due to NaN values in weights.
# Total iterations: 458
# Descent name: momentum
# Mu: 0.01
# Learning rate: 1.0
# Train Loss: nan
# Validation Loss: nan
# R^2 on training set: 1.0
# R^2 on training set: 1.0
# Training stopped due to NaN values in weights.
# Total iterations: 169
# Descent name: momentum
# Mu: 0.01
# Learning rate: 10.0
# Train Loss: nan
# Validation Loss: nan
# R^2 on training set: 1.0
# R^2 on training set: 1.0
# Total iterations: 5000
# Descent name: momentum
# Mu: 0.1
# Learning rate: 0.0001
# Train Loss: 0.4995911533975732
# Validation Loss: 0.5192831269206325
# R^2 on training set: 0.5955959246465627
# R^2 on training set: 0.5793327330031
# Convergence achieved after 2247 iterations.
# Total iterations: 2247
# Descent name: momentum
# Mu: 0.1
# Learning rate: 0.001
# Train Loss: 0.4982878889935635
# Validation Loss: 0.5192422365917024
# R^2 on training set: 0.596650878147361
# R^2 on training set: 0.5793658579440539
# Convergence achieved after 1669 iterations.
# Total iterations: 1669
# Descent name: momentum
# Mu: 0.1
# Learning rate: 0.01
# Train Loss: 0.495995663910598
# Validation Loss: 0.5167040651371468
# R^2 on training set: 0.5985063656972794
# R^2 on training set: 0.5814220111167733
# Convergence achieved after 301 iterations.
# Total iterations: 301
# Descent name: momentum
# Mu: 0.1
# Learning rate: 0.1
# Train Loss: 0.49577040354152824
# Validation Loss: 0.5164615557310491
# R^2 on training set: 0.5986887072192378
# R^2 on training set: 0.581618466121366
# Training stopped due to NaN values in weights.
# Total iterations: 447
# Descent name: momentum
# Mu: 0.1
# Learning rate: 1.0
# Train Loss: nan
# Validation Loss: nan
# R^2 on training set: 1.0
# R^2 on training set: 1.0
# Training stopped due to NaN values in weights.
# Total iterations: 168
# Descent name: momentum
# Mu: 0.1
# Learning rate: 10.0
# Train Loss: nan
# Validation Loss: nan
# R^2 on training set: 1.0
# R^2 on training set: 1.0
# Convergence achieved after 2169 iterations.
# Total iterations: 2169
# Descent name: momentum
# Mu: 1.0
# Learning rate: 0.0001
# Train Loss: 4.72485021031297
# Validation Loss: 4.7571865382048735
# R^2 on training set: -2.8246247306235657
# R^2 on training set: -2.8537602241925937
# Convergence achieved after 1149 iterations.
# Total iterations: 1149
# Descent name: momentum
# Mu: 1.0
# Learning rate: 0.001
# Train Loss: 4.727928670765855
# Validation Loss: 4.760282437410271
# R^2 on training set: -2.8271166521567923
# R^2 on training set: -2.8562681883264474
# Convergence achieved after 1789 iterations.
# Total iterations: 1789
# Descent name: momentum
# Mu: 1.0
# Learning rate: 0.01
# Train Loss: 4.737044139542731
# Validation Loss: 4.769256158447256
# R^2 on training set: -2.8344953511130417
# R^2 on training set: -2.8635377307161773
# Convergence achieved after 355 iterations.
# Total iterations: 355
# Descent name: momentum
# Mu: 1.0
# Learning rate: 0.1
# Train Loss: 4.738290656470706
# Validation Loss: 4.770535831153873
# R^2 on training set: -2.835504369231641
# R^2 on training set: -2.864574383733068
# Training stopped due to NaN values in weights.
# Total iterations: 370
# Descent name: momentum
# Mu: 1.0
# Learning rate: 1.0
# Train Loss: nan
# Validation Loss: nan
# R^2 on training set: 1.0
# R^2 on training set: 1.0
# Training stopped due to NaN values in weights.
# Total iterations: 159
# Descent name: momentum
# Mu: 1.0
# Learning rate: 10.0
# Train Loss: nan
# Validation Loss: nan
# R^2 on training set: 1.0
# R^2 on training set: 1.0
# Convergence achieved after 290 iterations.
# Total iterations: 290
# Descent name: momentum
# Mu: 10.0
# Learning rate: 0.0001
# Train Loss: 40.09390562569865
# Validation Loss: 39.98794314828554
# R^2 on training set: -31.45481574603759
# R^2 on training set: -31.39392517290036
# Total iterations: 5000
# Descent name: momentum
# Mu: 10.0
# Learning rate: 0.001
# Train Loss: 40.01138885611679
# Validation Loss: 39.88799999664774
# R^2 on training set: -31.38802089253194
# R^2 on training set: -31.31296199448198
# Convergence achieved after 3163 iterations.
# Total iterations: 3163
# Descent name: momentum
# Mu: 10.0
# Learning rate: 0.01
# Train Loss: 40.01518782369855
# Validation Loss: 39.886337448832236
# R^2 on training set: -31.391096043005987
# R^2 on training set: -31.311615177284303
# Convergence achieved after 440 iterations.
# Total iterations: 440
# Descent name: momentum
# Mu: 10.0
# Learning rate: 0.1
# Train Loss: 40.01651193856205
# Validation Loss: 39.88769904912325
# R^2 on training set: -31.392167874329246
# R^2 on training set: -31.31271819920716
# Training stopped due to NaN values in weights.
# Total iterations: 220
# Descent name: momentum
# Mu: 10.0
# Learning rate: 1.0
# Train Loss: nan
# Validation Loss: nan
# R^2 on training set: 1.0
# R^2 on training set: 1.0
# Overall Progress:  75%|███████▌  | 3/4 [17:35<05:56, 356.04s/it]
# Training stopped due to NaN values in weights.
# Total iterations: 128
# Descent name: momentum
# Mu: 10.0
# Learning rate: 10.0
# Train Loss: nan
# Validation Loss: nan
# R^2 on training set: 1.0
# R^2 on training set: 1.0
# Total iterations: 5000
# Descent name: adam
# Mu: 1e-06
# Learning rate: 0.0001
# Train Loss: 12.5705324536655
# Validation Loss: 12.520710707001742
# R^2 on training set: -9.175469519532259
# R^2 on training set: -9.142931439361528
# Total iterations: 5000
# Descent name: adam
# Mu: 1e-06
# Learning rate: 0.001
# Train Loss: 0.29427354093171865
# Validation Loss: 0.30678265057525406
# R^2 on training set: 0.761794382442218
# R^2 on training set: 0.7514777344204338
# Convergence achieved after 1131 iterations.
# Total iterations: 1131
# Descent name: adam
# Mu: 1e-06
# Learning rate: 0.01
# Train Loss: 0.29393222775998173
# Validation Loss: 0.3066818771885679
# R^2 on training set: 0.7620706652320223
# R^2 on training set: 0.7515593701658789
# Convergence achieved after 175 iterations.
# Total iterations: 175
# Descent name: adam
# Mu: 1e-06
# Learning rate: 0.1
# Train Loss: 0.2939287020351589
# Validation Loss: 0.3066691962058037
# R^2 on training set: 0.7620735192006669
# R^2 on training set: 0.7515696429324791
# Total iterations: 5000
# Descent name: adam
# Mu: 1e-06
# Learning rate: 1.0
# Train Loss: 0.3035356450961866
# Validation Loss: 0.3155592727323976
# R^2 on training set: 0.75429698653161
# R^2 on training set: 0.7443678603172563
# Total iterations: 5000
# Descent name: adam
# Mu: 1e-06
# Learning rate: 10.0
# Train Loss: 0.30126107644875544
# Validation Loss: 0.31375722035685094
# R^2 on training set: 0.7561381817257937
# R^2 on training set: 0.7458276890860087
# Total iterations: 5000
# Descent name: adam
# Mu: 1e-05
# Learning rate: 0.0001
# Train Loss: 9.35805447969294
# Validation Loss: 9.267768418874683
# R^2 on training set: -6.575064816961785
# R^2 on training set: -6.507747912102033
# Total iterations: 5000
# Descent name: adam
# Mu: 1e-05
# Learning rate: 0.001
# Train Loss: 0.29435196261460017
# Validation Loss: 0.30726067923670997
# R^2 on training set: 0.7617309024387438
# R^2 on training set: 0.7510904870785966
# Convergence achieved after 1033 iterations.
# Total iterations: 1033
# Descent name: adam
# Mu: 1e-05
# Learning rate: 0.01
# Train Loss: 0.2939345681371254
# Validation Loss: 0.30668732890970185
# R^2 on training set: 0.7620687707668214
# R^2 on training set: 0.7515549537685208
# Total iterations: 5000
# Descent name: adam
# Mu: 1e-05
# Learning rate: 0.1
# Train Loss: 0.2939307642986393
# Validation Loss: 0.30669902249233594
# R^2 on training set: 0.7620718498601466
# R^2 on training set: 0.7515454808871713
# Total iterations: 5000
# Descent name: adam
# Mu: 1e-05
# Learning rate: 1.0
# Train Loss: 0.294598393541514
# Validation Loss: 0.30719821722925467
# R^2 on training set: 0.7615314239842929
# R^2 on training set: 0.751141087070403
# Total iterations: 5000
# Descent name: adam
# Mu: 1e-05
# Learning rate: 10.0
# Train Loss: 1.093120432262913
# Validation Loss: 1.1182888998818843
# R^2 on training set: 0.11515175028041169
# R^2 on training set: 0.09408276364392143
# Total iterations: 5000
# Descent name: adam
# Mu: 0.0001
# Learning rate: 0.0001
# Train Loss: 7.390061464780304
# Validation Loss: 7.351016122617682
# R^2 on training set: -4.982033415013757
# R^2 on training set: -4.955001619808768
# Total iterations: 5000
# Descent name: adam
# Mu: 0.0001
# Learning rate: 0.001
# Train Loss: 0.2948400884178307
# Validation Loss: 0.30803112552249595
# R^2 on training set: 0.7613357792209503
# R^2 on training set: 0.7504663544684511
# Total iterations: 5000
# Descent name: adam
# Mu: 0.0001
# Learning rate: 0.01
# Train Loss: 0.294123041030904
# Validation Loss: 0.3071547228557912
# R^2 on training set: 0.7619162076042847
# R^2 on training set: 0.7511763215278041
# Total iterations: 5000
# Descent name: adam
# Mu: 0.0001
# Learning rate: 0.1
# Train Loss: 0.2939628128372781
# Validation Loss: 0.30684100859198393
# R^2 on training set: 0.7620459075280086
# R^2 on training set: 0.7514304590399477
# Convergence achieved after 4306 iterations.
# Total iterations: 4306
# Descent name: adam
# Mu: 0.0001
# Learning rate: 1.0
# Train Loss: 0.2939580874350262
# Validation Loss: 0.3068257367251063
# R^2 on training set: 0.7620497325996003
# R^2 on training set: 0.7514428306618401
# Total iterations: 5000
# Descent name: adam
# Mu: 0.0001
# Learning rate: 10.0
# Train Loss: 0.5317562656759457
# Validation Loss: 0.54094392305828
# R^2 on training set: 0.5695592296388288
# R^2 on training set: 0.5617854886583133
# Total iterations: 5000
# Descent name: adam
# Mu: 0.001
# Learning rate: 0.0001
# Train Loss: 5.4307924680349124
# Validation Loss: 5.390436316355584
# R^2 on training set: -3.3960638444778724
# R^2 on training set: -3.3667509987643376
# Total iterations: 5000
# Descent name: adam
# Mu: 0.001
# Learning rate: 0.001
# Train Loss: 0.30177534167057224
# Validation Loss: 0.3157340846381069
# R^2 on training set: 0.75572189943156
# R^2 on training set: 0.7442262465370255
# Total iterations: 5000
# Descent name: adam
# Mu: 0.001
# Learning rate: 0.01
# Train Loss: 0.2957858478059524
# Validation Loss: 0.30944525974969567
# R^2 on training set: 0.7605702153228325
# R^2 on training set: 0.7493207752079607
# Convergence achieved after 3958 iterations.
# Total iterations: 3958
# Descent name: adam
# Mu: 0.001
# Learning rate: 0.1
# Train Loss: 0.2948552967908903
# Validation Loss: 0.3082708312153564
# R^2 on training set: 0.7613234684984665
# R^2 on training set: 0.7502721707303868
# Convergence achieved after 1358 iterations.
# Total iterations: 1358
# Descent name: adam
# Mu: 0.001
# Learning rate: 1.0
# Train Loss: 0.29485290735040537
# Validation Loss: 0.30826718007385745
# R^2 on training set: 0.7613254026789726
# R^2 on training set: 0.7502751284920319
# Convergence achieved after 1267 iterations.
# Total iterations: 1267
# Descent name: adam
# Mu: 0.001
# Learning rate: 10.0
# Train Loss: 0.29485292184707573
# Validation Loss: 0.3082671792625884
# R^2 on training set: 0.7613253909443523
# R^2 on training set: 0.7502751291492347
# Total iterations: 5000
# Descent name: adam
# Mu: 0.01
# Learning rate: 0.0001
# Train Loss: 9.599205168059346
# Validation Loss: 9.559771140147776
# R^2 on training set: -6.770269076457654
# R^2 on training set: -6.744297070635319
# Total iterations: 5000
# Descent name: adam
# Mu: 0.01
# Learning rate: 0.001
# Train Loss: 0.3388185940281901
# Validation Loss: 0.3540382377548581
# R^2 on training set: 0.725736496135507
# R^2 on training set: 0.7131963467176208
# Total iterations: 5000
# Descent name: adam
# Mu: 0.01
# Learning rate: 0.01
# Train Loss: 0.3083770836569275
# Validation Loss: 0.32306957557419097
# R^2 on training set: 0.7503779870232684
# R^2 on training set: 0.738283821751414
# Convergence achieved after 1242 iterations.
# Total iterations: 1242
# Descent name: adam
# Mu: 0.01
# Learning rate: 0.1
# Train Loss: 0.30817755983510436
# Validation Loss: 0.32284434845399257
# R^2 on training set: 0.7505394955810694
# R^2 on training set: 0.7384662765091283
# Convergence achieved after 321 iterations.
# Total iterations: 321
# Descent name: adam
# Mu: 0.01
# Learning rate: 1.0
# Train Loss: 0.3081470399535927
# Validation Loss: 0.32281014264393776
# R^2 on training set: 0.750564200511048
# R^2 on training set: 0.7384939863727562
# Convergence achieved after 415 iterations.
# Total iterations: 415
# Descent name: adam
# Mu: 0.01
# Learning rate: 10.0
# Train Loss: 0.30798569511269897
# Validation Loss: 0.3226141445958763
# R^2 on training set: 0.7506948043272904
# R^2 on training set: 0.7386527628839508
# Total iterations: 5000
# Descent name: adam
# Mu: 0.1
# Learning rate: 0.0001
# Train Loss: 5.5690835101009935
# Validation Loss: 5.56249817000172
# R^2 on training set: -3.508006301056745
# R^2 on training set: -3.5061369829709905
# Total iterations: 5000
# Descent name: adam
# Mu: 0.1
# Learning rate: 0.001
# Train Loss: 0.5391791230131646
# Validation Loss: 0.5598446693324766
# R^2 on training set: 0.5635506489473494
# R^2 on training set: 0.5464741394786907
# Convergence achieved after 2168 iterations.
# Total iterations: 2168
# Descent name: adam
# Mu: 0.1
# Learning rate: 0.01
# Train Loss: 0.49710872321385324
# Validation Loss: 0.5178643836915803
# R^2 on training set: 0.5976053775286834
# R^2 on training set: 0.5804820459805405
# Convergence achieved after 368 iterations.
# Total iterations: 368
# Descent name: adam
# Mu: 0.1
# Learning rate: 0.1
# Train Loss: 0.4958976423187102
# Validation Loss: 0.5165981770407013
# R^2 on training set: 0.5985857112400548
# R^2 on training set: 0.5815077902492541
# Convergence achieved after 213 iterations.
# Total iterations: 213
# Descent name: adam
# Mu: 0.1
# Learning rate: 1.0
# Train Loss: 0.49578047123855196
# Validation Loss: 0.51647075630659
# R^2 on training set: 0.598680557720036
# R^2 on training set: 0.5816110128058876
# Convergence achieved after 264 iterations.
# Total iterations: 264
# Descent name: adam
# Mu: 0.1
# Learning rate: 10.0
# Train Loss: 0.49574789963920524
# Validation Loss: 0.5164380019480884
# R^2 on training set: 0.5987069234541509
# R^2 on training set: 0.5816375468597761
# Total iterations: 5000
# Descent name: adam
# Mu: 1.0
# Learning rate: 0.0001
# Train Loss: 13.776076662513354
# Validation Loss: 13.716419446348208
# R^2 on training set: -10.151321449177688
# R^2 on training set: -10.11156589218492
# Convergence achieved after 4039 iterations.
# Total iterations: 4039
# Descent name: adam
# Mu: 1.0
# Learning rate: 0.001
# Train Loss: 4.742214955775791
# Validation Loss: 4.774103578628799
# R^2 on training set: -2.83868097198189
# R^2 on training set: -2.867464588520797
# Convergence achieved after 636 iterations.
# Total iterations: 636
# Descent name: adam
# Mu: 1.0
# Learning rate: 0.01
# Train Loss: 4.742920254336071
# Validation Loss: 4.77527262669981
# R^2 on training set: -2.839251890041945
# R^2 on training set: -2.8684116253712646
# Convergence achieved after 180 iterations.
# Total iterations: 180
# Descent name: adam
# Mu: 1.0
# Learning rate: 0.1
# Train Loss: 4.738558556804845
# Validation Loss: 4.770814086469754
# R^2 on training set: -2.8357212265282072
# R^2 on training set: -2.8647997962242338
# Convergence achieved after 204 iterations.
# Total iterations: 204
# Descent name: adam
# Mu: 1.0
# Learning rate: 1.0
# Train Loss: 4.738476967654474
# Validation Loss: 4.770724398866234
# R^2 on training set: -2.83565518255467
# R^2 on training set: -2.8647271409864636
# Convergence achieved after 257 iterations.
# Total iterations: 257
# Descent name: adam
# Mu: 1.0
# Learning rate: 10.0
# Train Loss: 4.738426216073668
# Validation Loss: 4.770675340366294
# R^2 on training set: -2.835614100670075
# R^2 on training set: -2.8646873990730013
# Total iterations: 5000
# Descent name: adam
# Mu: 10.0
# Learning rate: 0.0001
# Train Loss: 36.80214946706725
# Validation Loss: 36.66395504900816
# R^2 on training set: -28.790237727457367
# R^2 on training set: -28.701187980484416
# Total iterations: 5000
# Descent name: adam
# Mu: 10.0
# Learning rate: 0.001
# Train Loss: 40.001230881288706
# Validation Loss: 39.873645971832424
# R^2 on training set: -31.379798316151486
# R^2 on training set: -31.301333909384603
# Convergence achieved after 1491 iterations.
# Total iterations: 1491
# Descent name: adam
# Mu: 10.0
# Learning rate: 0.01
# Train Loss: 40.016344484598925
# Validation Loss: 39.887526523941055
# R^2 on training set: -31.392032325361534
# R^2 on training set: -31.312578437884056
# Convergence achieved after 176 iterations.
# Total iterations: 176
# Descent name: adam
# Mu: 10.0
# Learning rate: 0.1
# Train Loss: 40.016738492433106
# Validation Loss: 39.887936702287824
# R^2 on training set: -31.392351262902324
# R^2 on training set: -31.312910720207846
# Convergence achieved after 208 iterations.
# Total iterations: 208
# Descent name: adam
# Mu: 10.0
# Learning rate: 1.0
# Train Loss: 40.01651025998183
# Validation Loss: 39.88769911093218
# R^2 on training set: -31.39216651556884
# R^2 on training set: -31.312718249278106
# Convergence achieved after 255 iterations.
# Total iterations: 255
# Descent name: adam
# Mu: 10.0
# Learning rate: 10.0
# Train Loss: 40.0165332001515
# Validation Loss: 39.88771900158735
# R^2 on training set: -31.392185084949098
# R^2 on training set: -31.31273436254486

# %%
for result in results:
    combined_results = [
        (
            lr,
            mu,
            history, 
            train_loss,  
            val_loss,  
            iterations, 
            r2_train,  
            r2_val  
        ) for (lr, mu, history, train_loss, val_loss, r2_train, r2_val), iterations in zip(result['loss_histories'], result['convergence_iterations'])
    ]
    
    best_lr, best_mu, best_history, best_train_loss, best_val_loss, best_iterations, best_r2_train, best_r2_val = min(
        combined_results,
        key=lambda x: x[4]  
    )
    
    descent_name = result['descent_name']
    print(f"Лучшие результаты для метода {descent_name}:")
    print(f"Оптимальное значение λ: {best_lr}")
    print(f"Оптимальное значение Mu: {best_mu}")
    print(f"Потеря на тренировочной выборке: {best_train_loss}")
    print(f"Потеря на валидационной выборке: {best_val_loss}")
    print(f"Количество итераций до сходимости: {best_iterations}")
    print(f"R^2 на тренировочной выборке: {best_r2_train}")
    print(f"R^2 на валидационной выборке: {best_r2_val}\n")
# Out:
# Лучшие результаты для метода full:
# Оптимальное значение λ: 1.0
# Оптимальное значение Mu: 1e-05
# Потеря на тренировочной выборке: 0.29660685685067745
# Потеря на валидационной выборке: 0.3098431657474281
# Количество итераций до сходимости: 3562
# R^2 на тренировочной выборке: 0.7599056330912801
# R^2 на валидационной выборке: 0.748998434619734
#
# Лучшие результаты для метода stochastic:
# Оптимальное значение λ: 0.1
# Оптимальное значение Mu: 1e-06
# Потеря на тренировочной выборке: 0.31763359271862185
# Потеря на валидационной выборке: 0.3310177545512579
# Количество итераций до сходимости: 5001
# R^2 на тренировочной выборке: 0.742885120180776
# R^2 на валидационной выборке: 0.7318450630963577
#
# Лучшие результаты для метода momentum:
# Оптимальное значение λ: 0.1
# Оптимальное значение Mu: 1e-05
# Потеря на тренировочной выборке: 0.2939447181809236
# Потеря на валидационной выборке: 0.3067046808775102
# Количество итераций до сходимости: 3539
# R^2 на тренировочной выборке: 0.762060554610372
# R^2 на валидационной выборке: 0.7515408970728638
#
# Лучшие результаты для метода adam:
# Оптимальное значение λ: 0.1
# Оптимальное значение Mu: 1e-06
# Потеря на тренировочной выборке: 0.2939287020351589
# Потеря на валидационной выборке: 0.3066691962058037
# Количество итераций до сходимости: 176
# R^2 на тренировочной выборке: 0.7620735192006669
# R^2 на валидационной выборке: 0.7515696429324791

# %%
import matplotlib.pyplot as plt

loss_history_full = []
loss_history_stochastic = []
loss_history_momentum = []
loss_history_adam = []

for result in results:
    optimal_loss_history = min(result['loss_histories'], key=lambda x: x[4])[2]  # x[4] это val_loss

    if result['descent_name'] == 'full':
        loss_history_full = optimal_loss_history
    elif result['descent_name'] == 'stochastic':
        loss_history_stochastic = optimal_loss_history
    elif result['descent_name'] == 'momentum':
        loss_history_momentum = optimal_loss_history
    elif result['descent_name'] == 'adam':
        loss_history_adam = optimal_loss_history

# print(loss_history_full)
iterations_full = range(len(loss_history_full))
iterations_stochastic = range(len(loss_history_stochastic))
iterations_momentum = range(len(loss_history_momentum))
iterations_adam = range(len(loss_history_adam))

plt.figure(figsize=(12, 8))

plt.plot(iterations_full, loss_history_full, label='Full', color='blue')
plt.plot(iterations_stochastic, loss_history_stochastic, label='Stochastic', color='red')
plt.plot(iterations_momentum, loss_history_momentum, label='Momentum', color='green')
plt.plot(iterations_adam, loss_history_adam, label='Adam', color='purple')

plt.title('Loss History for Different Gradient Descent Methods')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.ylim(0.25, 0.7)
plt.xlim(0, 700)


plt.show()

# %% [markdown]
# Full: Регуляризация помогает улучшить R^2 метрику на тренировочной и валидационной выборке. Количество итераций также уменьшилось, то есть процесс обучения более эффективен.
# Stochastic: Видим улучшение метрик на обоих выборках.
# Momentum, Adam: Незначительное улучшение после регуляризации.
# Сходимость выросла после применения регуляризации, но метрики качества улучшились незначительно. Регуляризацию целесообразно применять, когда есть переобучение(стохастический метод дал наилучшее улучшение).

# %% [markdown]
# ## Задание 8. Альтернативная функция потерь (0.5 балла)
#
# В этом задании вам предстоит использовать другую функцию потерь для нашей задачи регрессии. В качестве функции потерь мы выбрали **Log-Cosh**:
#
# $$
#     L(y, a)
#     =
#     \log({cosh{(a - y)}}).
# $$

# %% [markdown]
# Самостоятельно продифференцируйте данную функцию потерь чтобы найти её градиент:
#
# ╰( ͡☉ ͜ʖ ͡☉ )つ──☆*:・ﾟ   ฅ^•ﻌ•^ฅ   ʕ•ᴥ•ʔ

# %% [markdown]
# Программно реализуйте градиентный спуск с данной функцией потерь в файле `descents.py`, обучите все четыре метода (без регуляризации) аналогично 5 заданию, сравните их качество с четырьмя методами из 5 задания.
#
# Пример того, как можно запрограммировать использование нескольких функций потерь внутри одного класса градиентного спуска:
#
#
# ```python
# from enum import auto
# from enum import Enum
#
# import numpy as np
#
# class LossFunction(Enum):
#     MSE = auto()
#     MAE = auto()
#     LogCosh = auto()
#     Huber = auto()
#
# ...
# class BaseDescent:
#     def __init__(self, loss_function: LossFunction = LossFunction.MSE):
#         self.loss_function: LossFunction = loss_function
#
#     def calc_gradient(self, x: np.ndarray, y: np.ndarray) -> np.ndarray:
#         if self.loss_function is LossFunction.MSE:
#             return ...
#         elif self.loss_function is LossFunction.LogCosh:
#             return ...
# ...
#
# ```

# %% [markdown]
# Не успела, к сожалению(
